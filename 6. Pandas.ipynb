# %% [markdown]
# # Pandas

# %% [markdown]
# Requires cars.csv and cars_to_csv.csv files

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.3.4

# %% [markdown]
# Pandas has two main data structures:
#
# - Series
# - Dataframes

# %% [markdown]
# ### Series

# %% [markdown]
# A Pandas Series is like a column in a table. It is a one-dimensional array holding data of any type.

# %% [markdown]
# - Homogeneous data
# - Size Immutable
# - Values of Data Mutable

# %%
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
# Note: The keys of the dictionary become the labels(index)

calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2", "day4"])
print(myvar)
# Out:
# day1    420.0
# day2    380.0
# day4      NaN
# dtype: float64

# %% [markdown]
# ### DataFrame

# %% [markdown]
# Series is like a column, a DataFrame is the whole table.
#
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.

# %% [markdown]
# It is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns and heterogeneous data, with rows having an index each and columns having meaningful names.

# %% [markdown]
# - Heterogeneous data
# - Size Mutable
# - Data Mutable

# %%
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])
df
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %% [markdown]
# #### Creating datframe from a dictionary

# %% [markdown]
# pd.DataFrame(dictionary_name)

# %% [markdown]
# The ‘key’ in the dictionary acts as the column name and the ‘values’ stored are the entries under the column.

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
# Data in lists
# Construct dictionary
# Create dataframe from a dictionary

# %%
cars_per_cap = [809, 731, 588, 18, 200, 70, 45]
country = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
drives_right = [True, False, False, False, True, True, True]

# %%
data = {"cars_per_cap": cars_per_cap, "country": country, "drives_right": drives_right}

# %%
data
# Out:
# {'cars_per_cap': [809, 731, 588, 18, 200, 70, 45],
#  'country': ['United States',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Morocco',
#   'Egypt'],
#  'drives_right': [True, False, False, False, True, True, True]}

# %%
cars = pd.DataFrame(data)
cars
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True

# %%
# Refers to the row index
# Returns a Pandas Series

print(cars.loc[5])
# Out:
# cars_per_cap         70
# country         Morocco
# drives_right       True
# Name: 5, dtype: object

# %%
print(cars.loc[[5]])
# Out:
#    cars_per_cap  country  drives_right
# 5            70  Morocco          True

# %%
# When using [], the result is a Pandas DataFrame.

print(cars.loc[[0, 1]])
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
# Refer to the named index:
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)
df
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %% [markdown]
# #### Creating dataframes from external files

# %% [markdown]
# Data may not necessarily be available in the form of lists. Mostly, we will have to load the data stored in the form of a CSV file, text file, etc

# %% [markdown]
# pd.read_csv(filepath, sep=',', header='infer')

# %% [markdown]
# specify the following details:
#
# - separator (by default ‘,’)
# - header (takes the top row by default, if not specified)
# - names (list of column name)

# %%
# Read a file using pandas
# reads first row as header by default

cars_df = pd.read_csv('cars.csv')
cars_df
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %%
# Read file - skip header
cars_df = pd.read_csv('cars.csv', header=None)
cars_df
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
# Returns an array of headers

cars_df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %% [markdown]
# ##### Assign Headers

# %%
# Rename Headers

cars_df.columns = ['country code', 'region', 'country', 'cars_per_cap', 'drive_right']
cars_df
# Out:
#   country code region        country  cars_per_cap  drive_right
# 0         USCA     US  United States         809.0        False
# 1        ASPAC    AUS      Australia         731.0         True
# 2        ASPAC    JAP          Japan         588.0         True
# 3        ASPAC     IN          India          18.0         True
# 4        ASPAC     RU         Russia         200.0        False
# 5        LATAM    MOR        Morocco          70.0        False
# 6          AFR     EG          Egypt          45.0        False
# 7          EUR    ENG        England           NaN         True

# %%
df = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv", sep= "|", header=None)
print(df)
# Out:
#      0        1            2   3   4   5
# 0    1   Akshay  Mathematics  50  40  80
# 1    2   Mahima      English  40  33  83
# 2    3    Vikas  Mathematics  50  42  84
# 3    4  Abhinav      English  40  31  78
# 4    5   Mahima      Science  50  40  80
# 5    6   Akshay      Science  50  49  98
# 6    7  Abhinav  Mathematics  50  47  94
# 7    8    Vikas      Science  50  40  80
# 8    9  Abhinav      Science  50  47  94
# 9   10    Vikas      English  40  39  98
# 10  11   Akshay      English  40  35  88
# 11  12   Mahima  Mathematics  50  43  86

# %% [markdown]
# #### Assign first column as index

# %% [markdown]
# pd.read_csv(filepath, index_col = column_number)
# to change the index while loading the data from a file

# %%
# Read file and set 1st column as index
# Set first column as index

cars_df = pd.read_csv("cars.csv", header= None, index_col=0)
cars_df
# Out:
#          1              2      3      4
# 0
# USCA    US  United States  809.0  False
# ASPAC  AUS      Australia  731.0   True
# ASPAC  JAP          Japan  588.0   True
# ASPAC   IN          India   18.0   True
# ASPAC   RU         Russia  200.0  False
# LATAM  MOR        Morocco   70.0  False
# AFR     EG          Egypt   45.0  False
# EUR    ENG        England    NaN   True

# %%
# set the column names
cars_df.columns = ['region', 'country', 'cars_per_cap', 'drive_right']
cars_df
# Out:
#       region        country  cars_per_cap  drive_right
# 0
# USCA      US  United States         809.0        False
# ASPAC    AUS      Australia         731.0         True
# ASPAC    JAP          Japan         588.0         True
# ASPAC     IN          India          18.0         True
# ASPAC     RU         Russia         200.0        False
# LATAM    MOR        Morocco          70.0        False
# AFR       EG          Egypt          45.0        False
# EUR      ENG        England           NaN         True

# %%
# Print the new index
cars_df.index
# Out:
# Index(['USCA', 'ASPAC', 'ASPAC', 'ASPAC', 'ASPAC', 'LATAM', 'AFR', 'EUR'], dtype='object', name=0)

# %% [markdown]
# #### Rename the Index Name

# %%
cars_df.index.name = 'country_code'
cars_df
# Out:
#              region        country  cars_per_cap  drive_right
# country_code
# USCA             US  United States         809.0        False
# ASPAC           AUS      Australia         731.0         True
# ASPAC           JAP          Japan         588.0         True
# ASPAC            IN          India          18.0         True
# ASPAC            RU         Russia         200.0        False
# LATAM           MOR        Morocco          70.0        False
# AFR              EG          Egypt          45.0        False
# EUR             ENG        England           NaN         True

# %% [markdown]
# #### Delete the index name

# %%
cars_df.index.name = None
cars_df
# Out:
#       region        country  cars_per_cap  drive_right
# USCA      US  United States         809.0        False
# ASPAC    AUS      Australia         731.0         True
# ASPAC    JAP          Japan         588.0         True
# ASPAC     IN          India          18.0         True
# ASPAC     RU         Russia         200.0        False
# LATAM    MOR        Morocco          70.0        False
# AFR       EG          Egypt          45.0        False
# EUR      ENG        England           NaN         True

# %% [markdown]
# #### Set Hierarchical index

# %% [markdown]
# create a multilevel indexing for your dataframe

# %%
# Read file and set 1st column as index
cars_df = pd.read_csv("cars.csv", header= None)

# set the column names
cars_df.columns = ['country_code','region','country','cars_per_cap','drives_right']

cars_df.set_index(['region', 'country_code'], inplace=True)
cars_df
# Out:
#                            country  cars_per_cap  drives_right
# region country_code
# US     USCA          United States         809.0         False
# AUS    ASPAC             Australia         731.0          True
# JAP    ASPAC                 Japan         588.0          True
# IN     ASPAC                 India          18.0          True
# RU     ASPAC                Russia         200.0         False
# MOR    LATAM               Morocco          70.0         False
# EG     AFR                   Egypt          45.0         False
# ENG    EUR                 England           NaN          True

# %% [markdown]
# #### Write Data Frame to file

# %%
cars_df.to_csv('cars_to_csv.csv')

# %%
df = pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv", sep= "|", header=None, index_col=0)
df
# Out:
#           1            2   3   4   5
# 0
# 1    Akshay  Mathematics  50  40  80
# 2    Mahima      English  40  33  83
# 3     Vikas  Mathematics  50  42  84
# 4   Abhinav      English  40  31  78
# 5    Mahima      Science  50  40  80
# 6    Akshay      Science  50  49  98
# 7   Abhinav  Mathematics  50  47  94
# 8     Vikas      Science  50  40  80
# 9   Abhinav      Science  50  47  94
# 10    Vikas      English  40  39  98
# 11   Akshay      English  40  35  88
# 12   Mahima  Mathematics  50  43  86

# %%
df.columns= ["Name", "Subject", "Maximum Marks", "Marks Obtained", "Percentage"]
df
# Out:
#        Name      Subject  Maximum Marks  Marks Obtained  Percentage
# 0
# 1    Akshay  Mathematics             50              40          80
# 2    Mahima      English             40              33          83
# 3     Vikas  Mathematics             50              42          84
# 4   Abhinav      English             40              31          78
# 5    Mahima      Science             50              40          80
# 6    Akshay      Science             50              49          98
# 7   Abhinav  Mathematics             50              47          94
# 8     Vikas      Science             50              40          80
# 9   Abhinav      Science             50              47          94
# 10    Vikas      English             40              39          98
# 11   Akshay      English             40              35          88
# 12   Mahima  Mathematics             50              43          86

# %%
df.index.name = "S.No."
print(df)
# Out:
#           Name      Subject  Maximum Marks  Marks Obtained  Percentage
# S.No.
# 1       Akshay  Mathematics             50              40          80
# 2       Mahima      English             40              33          83
# 3        Vikas  Mathematics             50              42          84
# 4      Abhinav      English             40              31          78
# 5       Mahima      Science             50              40          80
# 6       Akshay      Science             50              49          98
# 7      Abhinav  Mathematics             50              47          94
# 8        Vikas      Science             50              40          80
# 9      Abhinav      Science             50              47          94
# 10       Vikas      English             40              39          98
# 11      Akshay      English             40              35          88
# 12      Mahima  Mathematics             50              43          86

# %% [markdown]
# - dataframe_name.head(): the dataframes may hold large volumes of data, it would be an inefficient approach to load the entire data whenever an operation is performed. This method loads a limited number of entries.
# - dataframe.info(): This method prints information about the dataframe, which includes the index data type and column data types, the count of non-null values and the memory used.
# - dataframe.describe(): This function produces descriptive statistics for the dataframe, that is, the central tendency (mean, median, min, max, etc.), dispersion, etc. It analyses the data and generates output for both numeric and non-numeric data types accordingly.

# %%
sales = pd.read_excel('sales.xlsx')
sales
# Out:
#           Market             Region  No_of_Orders    Profit      Sales
# 0         Africa     Western Africa           251 -12901.51   78476.06
# 1         Africa    Southern Africa            85  11768.58   51319.50
# 2         Africa       North Africa           182  21643.08   86698.89
# 3         Africa     Eastern Africa           110   8013.04   44182.60
# 4         Africa     Central Africa           103  15606.30   61689.99
# 5   Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6   Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7   Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8   Asia Pacific            Oceania           646  54734.02  408002.98
# 9   Asia Pacific       Eastern Asia           414  72805.10  315390.77
# 10  Asia Pacific       Central Asia            37  -2649.76    8190.74
# 11        Europe     Western Europe           964  82091.27  656637.14
# 12        Europe    Southern Europe           338  18911.49  215703.93
# 13        Europe    Northern Europe           367  43237.44  252969.09
# 14        Europe     Eastern Europe           241  25050.69  108258.93
# 15         LATAM      South America           496  12377.59  210710.49
# 16         LATAM    Central America           930  74679.54  461670.28
# 17         LATAM          Caribbean           288  13529.59  116333.05
# 18          USCA         Western US           490  44303.65  251991.83
# 19          USCA        Southern US           255  19991.83  148771.91
# 20          USCA         Eastern US           443  47462.04  264973.98
# 21          USCA         Central US           356  33697.43  170416.31
# 22          USCA             Canada            49   7246.62   26298.81

# %%
# Read file and set 1st two columns as index
# Set Hierarchical index


sales = pd.read_excel('sales.xlsx', index_col = [0,1])
sales
# Out:
#                                 No_of_Orders    Profit      Sales
# Market       Region
# Africa       Western Africa              251 -12901.51   78476.06
#              Southern Africa              85  11768.58   51319.50
#              North Africa                182  21643.08   86698.89
#              Eastern Africa              110   8013.04   44182.60
#              Central Africa              103  15606.30   61689.99
# Asia Pacific Western Asia                382 -16766.90  124312.24
#              Southern Asia               469  67998.76  351806.60
#              Southeastern Asia           533  20948.84  329751.38
#              Oceania                     646  54734.02  408002.98
#              Eastern Asia                414  72805.10  315390.77
#              Central Asia                 37  -2649.76    8190.74
# Europe       Western Europe              964  82091.27  656637.14
#              Southern Europe             338  18911.49  215703.93
#              Northern Europe             367  43237.44  252969.09
#              Eastern Europe              241  25050.69  108258.93
# LATAM        South America               496  12377.59  210710.49
#              Central America             930  74679.54  461670.28
#              Caribbean                   288  13529.59  116333.05
# USCA         Western US                  490  44303.65  251991.83
#              Southern US                 255  19991.83  148771.91
#              Eastern US                  443  47462.04  264973.98
#              Central US                  356  33697.43  170416.31
#              Canada                       49   7246.62   26298.81

# %% [markdown]
# #### Viewing the Data

# %%
# Default - returns top 5 rows
sales.head()
# Out:
#                         No_of_Orders    Profit     Sales
# Market Region
# Africa Western Africa            251 -12901.51  78476.06
#        Southern Africa            85  11768.58  51319.50
#        North Africa              182  21643.08  86698.89
#        Eastern Africa            110   8013.04  44182.60
#        Central Africa            103  15606.30  61689.99

# %%
# returns last 5 rows
sales.tail()
# Out:
#                     No_of_Orders    Profit      Sales
# Market Region
# USCA   Western US            490  44303.65  251991.83
#        Southern US           255  19991.83  148771.91
#        Eastern US            443  47462.04  264973.98
#        Central US            356  33697.43  170416.31
#        Canada                 49   7246.62   26298.81

# %% [markdown]
# #### Info About the Data

# %%
# Display the information about the data stored in data frame
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 23 entries, ('Africa', 'Western Africa') to ('USCA', 'Canada')
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No_of_Orders  23 non-null     int64
#  1   Profit        23 non-null     float64
#  2   Sales         23 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.6+ KB

# %%
# Name of each column, with the data type
# Number of rows and columns
# Index information 
# Data column information
# Non-Null values present in each column
# how much memory your DataFrame is using

# %%
# Display the statistical information about the data in dataframe
sales.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %%
sales["Profit"]
# Out:
# Market        Region
# Africa        Western Africa      -12901.51
#               Southern Africa      11768.58
#               North Africa         21643.08
#               Eastern Africa        8013.04
#               Central Africa       15606.30
# Asia Pacific  Western Asia        -16766.90
#               Southern Asia        67998.76
#               Southeastern Asia    20948.84
#               Oceania              54734.02
#               Eastern Asia         72805.10
#               Central Asia         -2649.76
# Europe        Western Europe       82091.27
#               Southern Europe      18911.49
#               Northern Europe      43237.44
#               Eastern Europe       25050.69
# LATAM         South America        12377.59
#               Central America      74679.54
#               Caribbean            13529.59
# USCA          Western US           44303.65
#               Southern US          19991.83
#               Eastern US           47462.04
#               Central US           33697.43
#               Canada                7246.62
# Name: Profit, dtype: float64

# %%
sales[["Profit"]]
# Out:
#                                   Profit
# Market       Region
# Africa       Western Africa    -12901.51
#              Southern Africa    11768.58
#              North Africa       21643.08
#              Eastern Africa      8013.04
#              Central Africa     15606.30
# Asia Pacific Western Asia      -16766.90
#              Southern Asia      67998.76
#              Southeastern Asia  20948.84
#              Oceania            54734.02
#              Eastern Asia       72805.10
#              Central Asia       -2649.76
# Europe       Western Europe     82091.27
#              Southern Europe    18911.49
#              Northern Europe    43237.44
#              Eastern Europe     25050.69
# LATAM        South America      12377.59
#              Central America    74679.54
#              Caribbean          13529.59
# USCA         Western US         44303.65
#              Southern US        19991.83
#              Eastern US         47462.04
#              Central US         33697.43
#              Canada              7246.62

# %%
# use to_string() to print the entire DataFrame

print(sales.to_string())
# Out:
#                                 No_of_Orders    Profit      Sales
# Market       Region
# Africa       Western Africa              251 -12901.51   78476.06
#              Southern Africa              85  11768.58   51319.50
#              North Africa                182  21643.08   86698.89
#              Eastern Africa              110   8013.04   44182.60
#              Central Africa              103  15606.30   61689.99
# Asia Pacific Western Asia                382 -16766.90  124312.24
#              Southern Asia               469  67998.76  351806.60
#              Southeastern Asia           533  20948.84  329751.38
#              Oceania                     646  54734.02  408002.98
#              Eastern Asia                414  72805.10  315390.77
#              Central Asia                 37  -2649.76    8190.74
# Europe       Western Europe              964  82091.27  656637.14
#              Southern Europe             338  18911.49  215703.93
#              Northern Europe             367  43237.44  252969.09
#              Eastern Europe              241  25050.69  108258.93
# LATAM        South America               496  12377.59  210710.49
#              Central America             930  74679.54  461670.28
#              Caribbean                   288  13529.59  116333.05
# USCA         Western US                  490  44303.65  251991.83
#              Southern US                 255  19991.83  148771.91
#              Eastern US                  443  47462.04  264973.98
#              Central US                  356  33697.43  170416.31
#              Canada                       49   7246.62   26298.81

# %%
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
print(df.describe())
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# std      5.806625   16.317469    1.791653    0.295959    63.655818
# min      2.200000   15.000000    0.400000    0.000000     0.000000
# 25%     15.500000   33.000000    2.700000    0.000000     0.000000
# 50%     19.300000   42.000000    4.000000    0.000000     0.520000
# 75%     22.800000   53.000000    4.900000    0.000000     6.570000
# max     33.300000  100.000000    9.400000    6.400000  1090.840000

# %%
print(df.columns)
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (517, 13)

# %% [markdown]
# #### max_rows

# %% [markdown]
# The number of rows returned is defined in Pandas option settings.

# %%
print(pd.options.display.max_rows)
# Out:
# 9999

# %% [markdown]
# If the DataFrame contains more than 60 rows, the print(df) statement will return only the headers and the first and last 5 rows.

# %%
# Increase the maximum number of rows to display the entire DataFrame

pd.options.display.max_rows = 9999

# %%
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/NMgEjwkAEGGQZBoNYGr9Ld7w0/rating.csv')
df
# Out:
#         ID Department     Office  Rating
# 0    U2F26    Finance  New Delhi     3.4
# 1    U2M61  Marketing  New Delhi     3.9
# 2    U1S15      Sales  New Delhi     2.8
# 3    U1H87         HR     Mumbai     2.1
# 4    U1S51      Sales  New Delhi     4.6
# 5    U1H78         HR  New Delhi     3.8
# 6    U3M65  Marketing  New Delhi     5.0
# 7    U3M44  Marketing  Bangalore     2.1
# 8    U3S75      Sales  Bangalore     4.3
# 9    U2H84         HR  Bangalore     4.3
# 10   U2S84      Sales     Mumbai     3.6
# 11   U1S50      Sales     Mumbai     4.7
# 12   U2F25    Finance  New Delhi     4.4
# 13   U1S75      Sales  Bangalore     3.0
# 14   U1H39         HR  New Delhi     4.2
# 15   U2F53    Finance  Bangalore     2.7
# 16   U1F53    Finance  Bangalore     3.7
# 17   U2S99      Sales  New Delhi     3.6
# 18   U3F41    Finance  New Delhi     4.9
# 19   U1F28    Finance  Bangalore     3.2
# 20   U2F43    Finance     Mumbai     3.8
# 21   U2H45         HR  New Delhi     3.7
# 22   U2H48         HR  Bangalore     2.8
# 23   U2S27      Sales  New Delhi     NaN
# New Delhi HR          U2H45     3.7
# Bangalore HR          U2H48     2.8
# New Delhi Sales       U2S27     NaN
# Bangalore Sales       U3S93     3.6
#           Finance     U1F15     3.3
#           Marketing   U1M67     2.7
# New Delhi HR          U3H94     2.5
#           Marketing   U3M49     2.1
# Mumbai    Sales       U2S69     4.7
#           Marketing   U3M39     NaN
# Bangalore Finance     U1F14     2.9
# Mumbai    Finance     U3F29     3.7
# Bangalore Sales       U2S18     3.2
# Mumbai    Finance     U1F59     4.1
# Bangalore Finance     U3F66     4.7
#           HR          U3H88     2.7
#           Marketing   U1M15     4.9
#           Finance     U3F52     2.4
#           Sales       U1S77     3.1
# Mumbai    Sales       U3S74     4.8
# Bangalore Marketing   U1M45     4.7
# Mumbai    Sales       U1S42     2.5
# Bangalore Sales       U2S40     4.6
#           Finance     U3F39     4.1
# New Delhi Marketing   U1M82     3.3
#           HR          U2H65     3.6
#           HR          U3H92     4.4
# Mumbai    HR          U1H42     4.8
# New Delhi Sales       U1S23     3.3
#           Sales       U3S24     4.4
# Bangalore HR          U1H73     4.2
#           Marketing   U1M58     4.0
# New Delhi Finance     U2F89     4.4
# Bangalore Finance     U3F77     2.6
# Mumbai    HR          U1H93     3.1
# Bangalore Marketing   U1M79     3.2
#           HR          U3H69     3.7
#           Sales       U2S80     3.0
#           Sales       U2S89     4.4
#           Finance     U2F14     2.1
#           Finance     U2F36     3.8
#           HR          U1H97     3.7
#           HR          U3H31     3.3
#           HR          U3H57     4.4
#           Marketing   U1M70     2.6
#           HR          U3H77     3.1
#           HR          U2H22     4.8
# Mumbai    Marketing   U3M80     3.5
#           HR          U2H88     3.7
#           Marketing   U3M67     3.5
# New Delhi Marketing   U3M79     2.8
#           Finance     U3F87     3.4
# Mumbai    Finance     U3F43     2.9
# Bangalore HR          U1H81     4.6
#           Marketing   U2M41     4.4
# New Delhi HR          U2H71     4.9
# Bangalore Sales       U1S60     5.0
#           HR          U2H60     5.0
# Mumbai    HR          U3H76     3.1
# Bangalore HR          U1H56     2.6
#           HR          U3H71     3.1
# Mumbai    Marketing   U3M99     3.8
#           Sales       U1S38     4.7
#           Marketing   U1M89     2.1
# Bangalore HR          U2H30     4.2
#           Sales       U3S27     2.9
# Mumbai    Finance     U1F99     4.4
#           Finance     U1F56     4.8
# Bangalore HR          U2H91     3.0
# Mumbai    Finance     U2F58     3.3
#           HR          U2H15     4.8
#           Finance     U3F50     NaN
# New Delhi Sales       U3S43     2.4
# Mumbai    Marketing   U3M23     2.5
# Bangalore HR          U1H12     4.6
# New Delhi Marketing   U1M52     2.2
#           Marketing   U3M92     2.2
# Mumbai    HR          U1H49     2.2
# Bangalore Marketing   U3M84     3.2
# New Delhi Finance     U1F88     4.5
#           HR          U1H61     2.5
# Bangalore Marketing   U1M61     4.1
#           Finance     U1F97     2.2
# New Delhi HR          U1H57     4.0
# Bangalore Finance     U2F17     2.3
#           Finance     U3F37     4.0
# New Delhi Sales       U2S92     4.6
# Mumbai    Marketing   U1M25     2.7
# New Delhi Finance     U2F63     3.9
# Mumbai    HR          U3H61     3.2
# Bangalore Marketing   U1M53     3.2
#           Finance     U3F25     4.6
# Mumbai    HR          U1H17     5.0
#           Marketing   U1M18     4.1
# Bangalore Sales       U2S38     3.0
# New Delhi HR          U2H49     4.0
#           HR          U3H96     4.2
# Bangalore Marketing   U3M72     4.9
#           Finance     U2F57     2.7
# Mumbai    Marketing   U1M95     2.6
# New Delhi Finance     U1F45     4.2
#           Marketing   U3M12     4.9
# Bangalore Marketing   U1M86     2.2
#           Sales       U2S23     2.9
# New Delhi Finance     U3F63     4.4
#           HR          U2H68     4.9
# Mumbai    Sales       U2S10     3.3
# Bangalore HR          U1H43     4.4
# New Delhi Marketing   U1M97     3.9
# Bangalore Marketing   U3M93     3.5
#           HR          U3H29     3.6
#           Finance     U2F66     2.6
#           Marketing   U3M24     4.0
# New Delhi Finance     U2F94     2.2
# Mumbai    HR          U1H59     4.4
#           Marketing   U2M27     4.7
# Bangalore Sales       U3S19     3.2
# Mumbai    Finance     U3F26     4.2
# Bangalore Sales       U1S40     3.8
# New Delhi Sales       U3S23     3.5
# Mumbai    Sales       U3S69     2.7
# Bangalore Sales       U1S69     2.9
# Mumbai    Sales       U1S93     2.6
# New Delhi Sales       U3S54     3.8
# Mumbai    HR          U1H24     4.8
# Bangalore HR          U2H93     3.9
# New Delhi Marketing   U1M11     2.3
# Mumbai    Finance     U2F20     2.9
#           Finance     U1F19     4.2
# Bangalore Finance     U1F98     2.2
# New Delhi Marketing   U2M68     3.6
#           Finance     U2F62     2.8
#           Sales       U2S76     2.1
# Mumbai    HR          U1H53     2.1
# New Delhi HR          U2H97     4.3
# Bangalore Marketing   U1M27     3.3
# Mumbai    Sales       U3S41     2.4
#           Finance     U2F79     3.8
# New Delhi Sales       U3S97     4.3
# Bangalore Sales       U3S25     2.5
# Mumbai    Finance     U1F16     3.5
# Bangalore Sales       U1S96     2.2
# New Delhi Finance     U2F19     4.2
#           HR          U2H80     4.1
# Bangalore Finance     U2F55     4.0
# Mumbai    Marketing   U2M84     3.5
# New Delhi Finance     U1F34     3.1
# Bangalore Sales       U2S32     2.6
# Mumbai    Sales       U3S52     4.9
#           HR          U2H72     3.3
# New Delhi HR          U1H86     2.9
#           HR          U2H75     3.6
#           Marketing   U3M85     4.0
# Mumbai    Sales       U2S53     4.3
# Bangalore Finance     U2F60     4.6
# Mumbai    HR          U1H64     3.6
#           Sales       U1S82     3.5
# New Delhi Finance     U2F48     3.3
# Mumbai    Finance     U3F90     3.1
#           Sales       U3S79     NaN
#           Marketing   U3M13     4.7
# Bangalore Marketing   U1M39     3.1
#           Finance     U2F95     3.4
#           HR          U3H10     3.8
# New Delhi Marketing   U2M67     2.9
#           Marketing   U1M43     3.2
# Bangalore Marketing   U2M72     2.8
#           Finance     U3F10     2.5
# New Delhi HR          U3H16     4.4
# Mumbai    Marketing   U1M34     3.8
#           Marketing   U1M88     4.3
# New Delhi Finance     U1F27     3.3
# Mumbai    Finance     U1F66     4.6
# Bangalore Sales       U1S61     3.1
#           Marketing   U3M51     3.1
# New Delhi Marketing   U1M68     2.4
# Bangalore Sales       U2S85     3.0
#           Sales       U1S76     3.2
#           Finance     U3F17     3.9
# New Delhi Sales       U1S83     2.4
#           HR          U3H40     3.9
#           HR          U3H33     2.4
# Bangalore Sales       U2S44     4.9
#           Sales       U2S70     4.8
#           HR          U3H39     3.4
# New Delhi Marketing   U3M98     4.9
# Mumbai    HR          U2H26     4.6
#           Marketing   U1M99     2.1
# Bangalore Sales       U2S63     4.2
# Mumbai    HR          U2H31     3.2
# Bangalore Marketing   U1M24     4.5
# New Delhi Marketing   U1M87     2.9
#           Finance     U1F55     2.7
# Mumbai    HR          U3H24     3.8
# New Delhi Sales       U1S79     4.8
#           Finance     U1F41     3.7
# Mumbai    Finance     U2F32     4.2
# New Delhi Marketing   U2M40     4.8
# Bangalore Finance     U3F48     2.1
# New Delhi Marketing   U3M88     3.5
# Bangalore Marketing   U2M99     3.4
#           Finance     U3F51     5.0
# Mumbai    HR          U1H46     2.3
# Bangalore HR          U3H14     3.5
# New Delhi HR          U1H16     2.9
#           Marketing   U3M10     3.3
# Bangalore HR          U1H55     3.8
# Mumbai    Finance     U1F47     2.5
#           Marketing   U1M40     3.3
#           Marketing   U3M57     4.8
# Bangalore Marketing   U2M18     2.3
# New Delhi Finance     U1F17     3.7
# Bangalore Finance     U2F64     4.3
# New Delhi HR          U2H96     4.0
# Mumbai    Finance     U1F71     3.6
# Bangalore HR          U2H89     4.3
# Mumbai    Sales       U2S74     3.4
# Bangalore HR          U2H34     2.8
# New Delhi Sales       U2S39     2.4
# Mumbai    HR          U3H20     4.2
#           Sales       U2S13     2.9
#           Marketing   U3M96     3.4
# New Delhi Finance     U2F52     2.1
#           HR          U2H23     4.2
# Bangalore HR          U3H70     3.7
#           Finance     U1F83     3.8
# Mumbai    Finance     U2F91     2.9
# New Delhi Finance     U2F96     4.5
# Mumbai    HR          U1H36     3.0
# Bangalore Finance     U2F99     4.8
# New Delhi HR          U1H27     3.4
# Mumbai    HR          U1H98     2.5
#           Sales       U2S36     2.4
#           Marketing   U2M89     3.2
# New Delhi Sales       U2S55     NaN
#           HR          U2H14     2.3
# Bangalore Marketing   U3M53     2.8
#           HR          U1H33     NaN
#           Marketing   U3M73     4.9
# New Delhi Sales       U2S49     4.0
# Mumbai    Sales       U2S58     3.1
#           HR          U1H29     2.6
# Bangalore Finance     U2F31     3.4
#           Sales       U3S65     3.5
# New Delhi HR          U3H52     4.7
#           Finance     U2F51     2.5
# Mumbai    Marketing   U2M20     4.4
# Bangalore Marketing   U2M62     2.7
# Mumbai    Finance     U3F13     2.2
#           Sales       U1S34     3.4
# New Delhi Marketing   U1M76     2.2
# Mumbai    Marketing   U2M95     2.1
#           Finance     U3F89     3.9
# New Delhi Finance     U1F65     4.4
# Bangalore Marketing   U1M50     3.6
# Mumbai    HR          U2H42     2.7
# Bangalore Marketing   U1M63     4.4
# New Delhi Finance     U1F43     4.0
#           HR          U1H91     2.8
# Bangalore HR          U2H92     2.8
# New Delhi Marketing   U2M55     4.4
# Bangalore Marketing   U1M66     4.1
#           Marketing   U2M50     3.4
# New Delhi HR          U1H58     NaN
#           Sales       U2S95     3.2
# Bangalore Finance     U1F18     2.8
# Mumbai    Sales       U3S80     4.2
#           Sales       U1S29     4.6
# New Delhi Finance     U1F44     2.6
#           Marketing   U3M69     2.5
#           HR          U1H90     4.9
# Bangalore Sales       U2S34     4.0
# New Delhi Marketing   U3M91     4.7
# Bangalore Sales       U1S86     4.9
#           Marketing   U2M81     2.4
#           Sales       U1S74     3.8
# New Delhi Sales       U2S47     2.4
# Bangalore Finance     U1F85     3.7
#           Marketing   U2M44     2.5
# Mumbai    Finance     U2F37     3.0
#           Finance     U3F24     2.2
# New Delhi HR          U3H60     3.4
# Mumbai    HR          U2H11     3.9
# New Delhi Marketing   U3M26     4.1
# Mumbai    Sales       U1S72     3.5
#           Sales       U1S99     2.6
# Bangalore Marketing   U2M34     4.4
# New Delhi Sales       U3S71     4.0
#           Finance     U3F16     4.1
#           Sales       U2S91     3.9
# Bangalore Finance     U3F18     2.1
# Mumbai    Finance     U3F70     4.2
# Bangalore HR          U3H83     3.0
# Mumbai    Marketing   U1M96     2.2
#           Finance     U2F44     4.1
# Bangalore Marketing   U3M78     5.0
# Mumbai    Sales       U3S85     2.2
#           Sales       U2S64     3.6
# New Delhi Marketing   U1M37     NaN
# Bangalore Marketing   U1M51     2.8
# New Delhi Finance     U3F12     3.1
# Bangalore Sales       U2S57     4.9
#           Marketing   U3M32     4.6
#           HR          U3H34     2.8
#           HR          U2H38     5.0
# New Delhi Sales       U2S83     3.7
# Bangalore Finance     U2F76     3.6
# Mumbai    HR          U3H93     3.2
#           HR          U1H18     2.2
# Bangalore Finance     U3F64     4.4
#           Finance     U2F23     2.8
# Mumbai    HR          U3H25     4.7
# Bangalore HR          U3H64     2.9
# Mumbai    Marketing   U1M29     2.6
# Bangalore Finance     U3F35     4.4
# Mumbai    Marketing   U2M38     4.6
# New Delhi Sales       U2S79     4.9
# Bangalore Finance     U3F22     3.9
# Mumbai    Finance     U3F34     3.8
#           Marketing   U2M42     2.6
# New Delhi Marketing   U3M68     2.6
#           HR          U2H66     4.3
#           Sales       U2S43     2.7
#           HR          U1H14     2.5
#           HR          U1H60     3.5
# Mumbai    Sales       U1S10     2.1
# Bangalore HR          U3H54     4.2
# New Delhi HR          U3H46     4.8
#           Finance     U2F59     4.3
# Mumbai    Finance     U2F42     4.3
#           Marketing   U2M35     4.7
# New Delhi Marketing   U3M25     2.5
# Mumbai    HR          U1H88     3.8
#           Finance     U3F94     3.4
#           Sales       U2S61     4.7
#           Finance     U3F84     2.5
# New Delhi Sales       U2S11     3.9
# Bangalore Finance     U1F32     2.8
# Mumbai    Finance     U1F70     4.0
# New Delhi Marketing   U1M90     2.3
# Bangalore Marketing   U2M33     3.6
# Mumbai    Sales       U3S55     3.4
# Bangalore Marketing   U1M83     3.5
# New Delhi Finance     U2F69     2.9
# Bangalore Marketing   U3M20     3.7
#           Marketing   U1M91     2.3
# Mumbai    Marketing   U2M78     3.3
# Bangalore Marketing   U2M23     4.2
# Mumbai    Sales       U1S19     3.8
#           Finance     U1F42     2.9
#           Marketing   U2M65     4.0
#           Sales       U3S64     2.1
# New Delhi Sales       U1S91     4.6
#           Finance     U3F69     3.7
# Bangalore Finance     U2F28     3.0
# Mumbai    Sales       U1S80     2.7
#           Sales       U1S47     3.9
# Bangalore Sales       U3S62     4.7
#           Finance     U2F92     3.2
# Mumbai    Marketing   U3M18     4.8
# Bangalore Marketing   U3M81     3.4
# New Delhi Sales       U3S48     2.7
#           HR          U3H66     3.3
# Mumbai    HR          U3H23     3.5
# New Delhi Marketing   U1M80     3.1
# Mumbai    Sales       U2S16     4.8
#           Finance     U1F20     2.4
# New Delhi Finance     U3F62     2.2
#           HR          U1H30     4.9
# Mumbai    Marketing   U1M41     4.6
# New Delhi Sales       U3S30     4.7
# Bangalore Marketing   U2M98     4.2
# Mumbai    Sales       U3S58     2.4
#           Sales       U3S56     4.1
# New Delhi HR          U1H68     4.4
# Bangalore Finance     U1F54     4.7
# New Delhi Sales       U2S51     3.2
# Bangalore HR          U3H74     2.2
# New Delhi HR          U1H38     4.9
# Bangalore Marketing   U1M17     3.2
# New Delhi Marketing   U3M31     3.3
#           Marketing   U3M19     4.8
# Bangalore HR          U1H40     4.4
#           Marketing   U2M82     3.9
#           Sales       U3S61     4.0
# New Delhi Sales       U3S53     2.3
#           Finance     U1F50     4.0
# Bangalore Sales       U1S21     3.5
# Mumbai    HR          U1H15     2.2
# New Delhi Marketing   U3M70     4.5
# Mumbai    Finance     U1F48     3.0
#           Finance     U2F74     4.2
# New Delhi Finance     U2F45     2.6
#           Finance     U2F56     2.6
# Bangalore Sales       U1S32     4.5
# New Delhi HR          U2H85     3.8
# Mumbai    Marketing   U2M31     3.5
# Bangalore Finance     U1F69     5.0
# New Delhi Finance     U3F49     2.4
#           Marketing   U1M78     3.2
# Mumbai    Finance     U2F13     3.4
# New Delhi Marketing   U2M39     4.7
# Bangalore Sales       U1S92     3.3
# New Delhi Sales       U3S45     3.9
# Bangalore Marketing   U2M28     4.1
# Mumbai    Finance     U1F94     2.9
# New Delhi HR          U3H38     3.2
#           Marketing   U2M30     3.9
#           Finance     U1F87     4.0
# Mumbai    Finance     U2F38     2.3
# New Delhi Finance     U3F19     4.5
# Bangalore Marketing   U3M48     3.7
# Mumbai    Sales       U3S35     2.1
#           Sales       U1S73     3.4
#           Marketing   U1M72     2.6
# Bangalore Marketing   U3M64     4.6
# Mumbai    Marketing   U3M37     4.8
#           HR          U2H40     4.6
# Bangalore Marketing   U1M14     2.3
# New Delhi Sales       U3S31     3.6
# Mumbai    Marketing   U2M93     4.0
# New Delhi Sales       U2S37     3.1
# Bangalore Finance     U2F54     2.2
#           HR          U3H67     2.5
#           Sales       U2S17     4.4
#           Finance     U3F83     2.3
# Mumbai    Finance     U3F78     4.0
# New Delhi HR          U3H13     4.3
# Mumbai    Marketing   U2M91     2.4
# New Delhi HR          U1H76     3.6
# Bangalore HR          U2H77     4.4
#           HR          U3H97     4.6
# Mumbai    HR          U2H70     3.4
# New Delhi HR          U2H82     2.9
#           HR          U2H54     3.0
# Bangalore HR          U3H89     4.3
# New Delhi Marketing   U2M37     2.6
#           Sales       U3S14     2.3
#           Marketing   U2M96     4.9
# Bangalore HR          U2H56     4.9
#           Sales       U3S60     4.8
#           Marketing   U2M16     4.7
#           Finance     U1F95     4.4
# New Delhi Marketing   U2M58     4.0
#           HR          U2H69     3.0
# Bangalore Finance     U1F51     2.5
# Mumbai    Finance     U3F15     4.0
# Bangalore Sales       U2S45     4.8
# Mumbai    Sales       U3S34     4.8
# New Delhi Finance     U2F35     2.7
# Mumbai    HR          U3H84     2.1
# Bangalore Sales       U2S71     3.7
# New Delhi Sales       U3S77     3.1
# Mumbai    Finance     U2F80     3.0
#           HR          U2H95     3.5
# Bangalore Marketing   U2M21     4.6
# Mumbai    Finance     U3F81     4.3
# Bangalore Sales       U1S36     4.3
# Mumbai    HR          U2H86     3.5
# Bangalore Sales       U2S59     2.5
# Mumbai    Finance     U2F61     3.2
# New Delhi Marketing   U3M75     2.7
# Bangalore Sales       U2S82     2.4
#           Sales       U1S12     2.1
#           HR          U3H37     4.5
# New Delhi Marketing   U1M65     4.3
#           Sales       U3S11     3.6
# Mumbai    Marketing   U1M64     2.3
# New Delhi Finance     U3F82     4.8
# Bangalore Marketing   U3M97     2.2
# New Delhi Marketing   U3M16     2.1
#           Sales       U2S42     3.1
# Bangalore Finance     U1F21     4.3
# Mumbai    Sales       U2S52     NaN
# Bangalore Finance     U1F75     4.1
#           Marketing   U1M13     2.7
#           Finance     U2F65     4.2
# New Delhi HR          U2H57     3.9
# Bangalore HR          U2H41     4.0
# Mumbai    HR          U2H94     3.7
# Bangalore Sales       U1S94     2.9
# Mumbai    Finance     U3F65     3.2
# New Delhi Marketing   U2M15     2.6
# Mumbai    Sales       U1S55     3.9
#           Marketing   U3M61     3.4
# Bangalore HR          U3H15     3.9
# New Delhi HR          U1H25     3.0
# Bangalore HR          U3H28     4.8
# New Delhi HR          U3H73     4.0
# Mumbai    Sales       U3S40     3.4
# New Delhi HR          U1H70     3.4
# Mumbai    Marketing   U1M47     4.8
# Bangalore HR          U3H87     3.7
# New Delhi HR          U3H91     3.1
#           Marketing   U3M36     2.5
#           Sales       U3S36     4.5
#           Sales       U3S57     4.2
#           Finance     U2F27     3.2
#           Marketing   U1M57     4.9
# Mumbai    Marketing   U1M10     3.7
# New Delhi Finance     U1F93     2.1
# Mumbai    Sales       U2S41     3.4
# New Delhi Finance     U3F46     3.6
#           Marketing   U1M31     4.6
#           Sales       U1S25     3.4
# Mumbai    Sales       U2S35     4.9
# Bangalore Sales       U1S22     3.4
# New Delhi Sales       U3S44     4.8
# Bangalore Marketing   U2M11     2.5
#           Finance     U3F53     3.2
#           Sales       U3S46     2.9
# New Delhi Sales       U3S28     2.9

# %%
# Print the first 5 rows as the output.
df.head()
# Out:
#                          ID  Rating
# Office    Department
# New Delhi Finance     U2F26     3.4
#           Marketing   U2M61     3.9
#           Sales       U1S15     2.8
# Mumbai    HR          U1H87     2.1
# New Delhi Sales       U1S51     4.6

# %%
df[:10]
# Out:
#                          ID  Rating
# Office    Department
# New Delhi Finance     U2F26     3.4
#           Marketing   U2M61     3.9
#           Sales       U1S15     2.8
# Mumbai    HR          U1H87     2.1
# New Delhi Sales       U1S51     4.6
#           HR          U1H78     3.8
#           Marketing   U3M65     5.0
# Bangalore Marketing   U3M44     2.1
#           Sales       U3S75     4.3
#           HR          U2H84     4.3

# %% [markdown]
# ### Indexing

# %% [markdown]
# - Select rows from a dataframe
# - Select columns from a dataframe
# - Select subsets of dataframes

# %% [markdown]
# df[start_index:end_index] will subset the rows according to the start and end indices.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>NOTE</b>
#
# - df['column'] or df.column: It returns a series
# - df[['col_x', 'col_y']]: It returns a dataframe
#
# </div>

# %%
sales = pd.read_excel('sales.xlsx', index_col = [1])
sales
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Western Africa           Africa           251 -12901.51   78476.06
# Southern Africa          Africa            85  11768.58   51319.50
# North Africa             Africa           182  21643.08   86698.89
# Eastern Africa           Africa           110   8013.04   44182.60
# Central Africa           Africa           103  15606.30   61689.99
# Western Asia       Asia Pacific           382 -16766.90  124312.24
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98
# Eastern Asia       Asia Pacific           414  72805.10  315390.77
# Central Asia       Asia Pacific            37  -2649.76    8190.74
# Western Europe           Europe           964  82091.27  656637.14
# Southern Europe          Europe           338  18911.49  215703.93
# Northern Europe          Europe           367  43237.44  252969.09
# Eastern Europe           Europe           241  25050.69  108258.93
# South America             LATAM           496  12377.59  210710.49
# Central America           LATAM           930  74679.54  461670.28
# Caribbean                 LATAM           288  13529.59  116333.05
# Western US                 USCA           490  44303.65  251991.83
# Southern US                USCA           255  19991.83  148771.91
# Eastern US                 USCA           443  47462.04  264973.98
# Central US                 USCA           356  33697.43  170416.31
# Canada                     USCA            49   7246.62   26298.81

# %% [markdown]
# #### Column Indexing

# %%
sales["Sales"]
# Out:
# Region
# Western Africa        78476.06
# Southern Africa       51319.50
# North Africa          86698.89
# Eastern Africa        44182.60
# Central Africa        61689.99
# Western Asia         124312.24
# Southern Asia        351806.60
# Southeastern Asia    329751.38
# Oceania              408002.98
# Eastern Asia         315390.77
# Central Asia           8190.74
# Western Europe       656637.14
# Southern Europe      215703.93
# Northern Europe      252969.09
# Eastern Europe       108258.93
# South America        210710.49
# Central America      461670.28
# Caribbean            116333.05
# Western US           251991.83
# Southern US          148771.91
# Eastern US           264973.98
# Central US           170416.31
# Canada                26298.81
# Name: Sales, dtype: float64

# %%
sales.Sales
# Out:
# Region
# Western Africa        78476.06
# Southern Africa       51319.50
# North Africa          86698.89
# Eastern Africa        44182.60
# Central Africa        61689.99
# Western Asia         124312.24
# Southern Asia        351806.60
# Southeastern Asia    329751.38
# Oceania              408002.98
# Eastern Asia         315390.77
# Central Asia           8190.74
# Western Europe       656637.14
# Southern Europe      215703.93
# Northern Europe      252969.09
# Eastern Europe       108258.93
# South America        210710.49
# Central America      461670.28
# Caribbean            116333.05
# Western US           251991.83
# Southern US          148771.91
# Eastern US           264973.98
# Central US           170416.31
# Canada                26298.81
# Name: Sales, dtype: float64

# %%
type(sales["Sales"])
# Out:
# pandas.core.series.Series

# %%
# Display Sales and Profit Column together

sales[["Sales", "Profit"]]
# Out:
#                        Sales    Profit
# Region
# Western Africa      78476.06 -12901.51
# Southern Africa     51319.50  11768.58
# North Africa        86698.89  21643.08
# Eastern Africa      44182.60   8013.04
# Central Africa      61689.99  15606.30
# Western Asia       124312.24 -16766.90
# Southern Asia      351806.60  67998.76
# Southeastern Asia  329751.38  20948.84
# Oceania            408002.98  54734.02
# Eastern Asia       315390.77  72805.10
# Central Asia         8190.74  -2649.76
# Western Europe     656637.14  82091.27
# Southern Europe    215703.93  18911.49
# Northern Europe    252969.09  43237.44
# Eastern Europe     108258.93  25050.69
# South America      210710.49  12377.59
# Central America    461670.28  74679.54
# Caribbean          116333.05  13529.59
# Western US         251991.83  44303.65
# Southern US        148771.91  19991.83
# Eastern US         264973.98  47462.04
# Central US         170416.31  33697.43
# Canada              26298.81   7246.62

# %%
# Print out the columns 'month', 'day', 'temp', 'area' from the dataframe 'df'.

df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df[['month', 'day', 'temp', 'area']].head()
# Out:
#   month  day  temp  area
# 0   mar  fri   8.2   0.0
# 1   oct  tue  18.0   0.0
# 2   oct  sat  14.6   0.0
# 3   mar  fri   8.3   0.0
# 4   mar  sun  11.4   0.0

# %%
sales.head(10)
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Western Africa           Africa           251 -12901.51   78476.06
# Southern Africa          Africa            85  11768.58   51319.50
# North Africa             Africa           182  21643.08   86698.89
# Eastern Africa           Africa           110   8013.04   44182.60
# Central Africa           Africa           103  15606.30   61689.99
# Western Asia       Asia Pacific           382 -16766.90  124312.24
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98
# Eastern Asia       Asia Pacific           414  72805.10  315390.77

# %% [markdown]
# #### Row Indexing

# %%
# loc accessor takes row index and column index
# display data at "Southern Asia" index

sales.loc["Southern Asia"]
# Out:
# Market          Asia Pacific
# No_of_Orders             469
# Profit              67998.76
# Sales               351806.6
# Name: Southern Asia, dtype: object

# %%
# display "Sales" data at "Southern Asia" index

sales.loc["Southern Asia", "Sales"]
# Out:
# 351806.6

# %%
# iloc accessor takes row number and column number
sales.iloc[6]
# Out:
# Market          Asia Pacific
# No_of_Orders             469
# Profit              67998.76
# Sales               351806.6
# Name: Southern Asia, dtype: object

# %%
sales.iloc[6,3]
# Out:
# 351806.6

# %% [markdown]
# #### Selection by Label: loc function

# %%
# label-based indexing
# loc method to extract rows and columns from a dataframe based on the  labels
# dataframe.loc[[list_of_row_labels], [list_of_column_labels]]

# %%
sales.loc["Southern Asia", "Sales"]
# Out:
# 351806.6

# %% [markdown]
# #### Selection by integer location: iloc function

# %%
# position-based indexing
# row or column number instead of labels
# dataframe.iloc[rows, columns]

# %%
sales.iloc[6,-1]
# Out:
# 351806.6

# %% [markdown]
# ### Slicing

# %%
# All rows, Profit and Sales columns

sales.loc[: , ["Profit" , "Sales"]].head()
# Out:
#                    Profit     Sales
# Region
# Western Africa  -12901.51  78476.06
# Southern Africa  11768.58  51319.50
# North Africa     21643.08  86698.89
# Eastern Africa    8013.04  44182.60
# Central Africa   15606.30  61689.99

# %%
sales.iloc[: , [2,3]].head()
# Out:
#                    Profit     Sales
# Region
# Western Africa  -12901.51  78476.06
# Southern Africa  11768.58  51319.50
# North Africa     21643.08  86698.89
# Eastern Africa    8013.04  44182.60
# Central Africa   15606.30  61689.99

# %%
# Display data for Western Africa Southern Africa and North Africa

# %%
sales.loc[["Western Africa", "Southern Africa", "North Africa"]]
# Out:
#                  Market  No_of_Orders    Profit     Sales
# Region
# Western Africa   Africa           251 -12901.51  78476.06
# Southern Africa  Africa            85  11768.58  51319.50
# North Africa     Africa           182  21643.08  86698.89

# %%
sales.iloc[0:3 , :]
# Out:
#                  Market  No_of_Orders    Profit     Sales
# Region
# Western Africa   Africa           251 -12901.51  78476.06
# Southern Africa  Africa            85  11768.58  51319.50
# North Africa     Africa           182  21643.08  86698.89

# %%
# Display Sales and Profit data for Western Africa Southern Africa and North Africa

# %%
sales.loc[["Western Africa", "Southern Africa", "North Africa"] , ["Sales", "Profit"]]
# Out:
#                     Sales    Profit
# Region
# Western Africa   78476.06 -12901.51
# Southern Africa  51319.50  11768.58
# North Africa     86698.89  21643.08

# %%
sales.iloc[0:3 , -2:]
# Out:
#                    Profit     Sales
# Region
# Western Africa  -12901.51  78476.06
# Southern Africa  11768.58  51319.50
# North Africa     21643.08  86698.89

# %%
# Print only the even numbers of rows of the dataframe 'df'.

# %%
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df.iloc[2: :2 , ].head()
# Out:
#     X  Y month  day  FFMC    DMC     DC  ISI  temp  RH  wind  rain  area
# 2   7  4   oct  sat  90.6   43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 4   8  6   mar  sun  89.3   51.3  102.2  9.6  11.4  99   1.8   0.0   0.0
# 6   8  6   aug  mon  92.3   88.9  495.6  8.5  24.1  27   3.1   0.0   0.0
# 8   8  6   sep  tue  91.0  129.5  692.6  7.0  13.1  63   5.4   0.0   0.0
# 10  7  5   sep  sat  92.5   88.0  698.6  7.1  17.8  51   7.2   0.0   0.0

# %% [markdown]
# ### Subsetting rows based on conditions

# %% [markdown]
# - isin() : Similar to the membership operator in lists, this function can check if the given element "is in" the collection of elements provided.
# - isna() : It checks whether the given element is null/empty.

# %%
sales.head()
# Out:
#                  Market  No_of_Orders    Profit     Sales
# Region
# Western Africa   Africa           251 -12901.51  78476.06
# Southern Africa  Africa            85  11768.58  51319.50
# North Africa     Africa           182  21643.08  86698.89
# Eastern Africa   Africa           110   8013.04  44182.60
# Central Africa   Africa           103  15606.30  61689.99

# %%
# Display the LATAM and Eruopean countries with sales > 250000

sales[ (sales["Market"].isin(["LATAM", "Europe"]))  & (sales["Sales"] > 250000)]
# Out:
#                  Market  No_of_Orders    Profit      Sales
# Region
# Western Europe   Europe           964  82091.27  656637.14
# Northern Europe  Europe           367  43237.44  252969.09
# Central America   LATAM           930  74679.54  461670.28

# %%
# Print all the columns and the rows where 'area' is greater than 0, 'wind' is greater than 1 and the 'temp' is greater than 15.

# %%
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df[ (df["area"] > 0) & (df["wind"] > 1) & (df["temp"] > 15)]. head()
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 138  9  9   jul  tue  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0  0.36
# 139  1  4   sep  tue  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0  0.43
# 140  2  5   sep  mon  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0  0.47
# 141  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0  0.55
# 142  8  6   aug  fri  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0  0.61

# %% [markdown]
# ### Function Application

# %% [markdown]
# - Table wise Function Application: pipe()
# - Row or Column Wise Function Application: apply()
# - Element wise Function Application: applymap()

# %% [markdown]
# https://www.tutorialspoint.com/python_pandas/python_pandas_function_application.htm

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(5,3),columns=['col1','col2','col3'])
df.apply(np.mean)
# Out:
# col1    0.518931
# col2    0.674032
# col3   -0.145885
# dtype: float64

# %%
df = pd.DataFrame(np.random.randn(5,3),columns=['col1','col2','col3'])
df.apply(np.mean,axis=1)
# Out:
# 0    0.019079
# 1   -0.190633
# 2    0.697530
# 3   -0.170316
# 4   -0.575338
# dtype: float64

# %%
temp = df.apply(lambda x: x.max() - x.min())

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
df=pd.DataFrame(np.arange(0,20).reshape(5,4),index=['Row1','Row2','Row3','Row4','Row5'],columns=["Column1","Column2","Column3","Coumn4"])

# %%
df
# Out:
#       Column1  Column2  Column3  Coumn4
# Row1        0        1        2       3
# Row2        4        5        6       7
# Row3        8        9       10      11
# Row4       12       13       14      15
# Row5       16       17       18      19

# %%
type(df.loc["Row1"])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:2 , 0:2]
# Out:
#       Column1  Column2
# Row1        0        1
# Row2        4        5

# %%
type(df.iloc[0:2 , 0:2])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0:2 , 0]
# Out:
# Row1    0
# Row2    4
# Name: Column1, dtype: int32

# %%
type(df.iloc[0:2 , 0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# You are provided with the dataset of a company which has offices across three cities - Mumbai, Bangalore and New Delhi. The dataset contains the rating (out of 5) of all the employees from different departments (Finance, HR, Marketing and Sales).
#
#
#
# The company has come up with a new policy that any individual with a rating equal to or below 3.5 needs to attend a training. Using dataframes, load the dataset and then derive the column ‘Training’ which shows ‘Yes’ for people who require training and ‘No’ for those who do not.

# %%
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/NMgEjwkAEGGQZBoNYGr9Ld7w0/rating.csv')
df.head()
# Out:
#       ID Department     Office  Rating
# 0  U2F26    Finance  New Delhi     3.4
# 1  U2M61  Marketing  New Delhi     3.9
# 2  U1S15      Sales  New Delhi     2.8
# 3  U1H87         HR     Mumbai     2.1
# 4  U1S51      Sales  New Delhi     4.6

# %%
df["Training"] = df["Rating"].apply(lambda x: "Yes" if x<=3.5 else "No")
df.head()
# Out:
#       ID Department     Office  Rating Training
# 0  U2F26    Finance  New Delhi     3.4      Yes
# 1  U2M61  Marketing  New Delhi     3.9       No
# 2  U1S15      Sales  New Delhi     2.8      Yes
# 3  U1H87         HR     Mumbai     2.1      Yes
# 4  U1S51      Sales  New Delhi     4.6       No

# %%
df.Department.value_counts()
# Out:
# Marketing    138
# Finance      134
# HR           131
# Sales        130
# Name: Department, dtype: int64

# %%
# Most efficient team

for i in ['Finance', 'HR', 'Sales', 'Marketing']:
    print(i, len(df[(df['Training'] == 'No') & (df['Department'] == i)]) / len(df[df['Department'] == i]) * 100)
# Out:
# Finance 50.0
# HR 57.25190839694656
# Sales 49.23076923076923
# Marketing 46.3768115942029

# %%
# Group the dataframe 'df' by 'month' and 'day' and find the mean value for column 'rain' and 'wind'.

df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
groupby_df = df.groupby(by =["month","day"]).mean()

# %%
groupby_df[["rain", "wind"]].head()
# Out:
#            rain      wind
# month day
# apr   fri   0.0  3.100000
#       mon   0.0  3.100000
#       sat   0.0  4.500000
#       sun   0.0  5.666667
#       thu   0.0  5.800000

# %%
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
# Apply Aggregation on a Single Column of a Dataframe

df['temp'].aggregate(np.sum)
# Out:
# 9765.699999999999

# %%
# Apply Aggregation on Multiple Columns of a DataFrame

df[['temp', 'RH']].aggregate(np.sum)
# Out:
# temp     9765.7
# RH      22897.0
# dtype: float64

# %%
# Apply Multiple Functions on a Single Column of a DataFrame

df['temp'].aggregate([np.sum, np.mean])
# Out:
# sum     9765.700000
# mean      18.889168
# Name: temp, dtype: float64

# %%
# Apply Multiple Functions on Multiple Columns of a DataFrame

df[['temp', 'RH']].aggregate([np.sum, np.mean])
# Out:
#              temp            RH
# sum   9765.700000  22897.000000
# mean    18.889168     44.288201

# %%
# Apply Different Functions to Different Columns of a Dataframe

df.aggregate({"temp": np.sum,"RH": np.mean})
# Out:
# temp    9765.700000
# RH        44.288201
# dtype: float64

# %% [markdown]
# ### GroupBy

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

# %%
df.head()
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# 4   Kings     3  2014     741

# %% [markdown]
# Split Data into Groups
#
#
# Pandas object can be split into any of their objects. There are multiple ways to split an object like −
#
# - obj.groupby('key')
# - obj.groupby(['key1','key2'])
# - obj.groupby(key,axis=1)

# %%
# View Groups
df.groupby('Team').groups
# Out:
# {'Devils': [2, 3], 'Kings': [4, 6, 7], 'Riders': [0, 1, 8, 11], 'Royals': [9, 10], 'kings': [5]}

# %%
df.groupby(['Team','Year']).groups
# Out:
# {('Devils', 2014): [2], ('Devils', 2015): [3], ('Kings', 2014): [4], ('Kings', 2016): [6], ('Kings', 2017): [7], ('Riders', 2014): [0], ('Riders', 2015): [1], ('Riders', 2016): [8], ('Riders', 2017): [11], ('Royals', 2014): [9], ('Royals', 2015): [10], ('kings', 2015): [5]}

# %%
# get_group() method -> select a single group

df.groupby('Year').get_group(2014)
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701

# %%
df.groupby('Year')['Points'].agg(np.mean)
# Out:
# Year
# 2014    795.25
# 2015    769.50
# 2016    725.00
# 2017    739.00
# Name: Points, dtype: float64

# %%
df.groupby('Team')['Points'].agg([np.sum, np.mean, np.std])
# Out:
#          sum        mean         std
# Team
# Devils  1536  768.000000  134.350288
# Kings   2285  761.666667   24.006943
# Riders  3049  762.250000   88.567771
# Royals  1505  752.500000   72.831998
# kings    812  812.000000         NaN

# %%
df.head()
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# 4   Kings     3  2014     741

# %%
df.groupby('Team').groups
# Out:
# {'Devils': [2, 3], 'Kings': [4, 6, 7], 'Riders': [0, 1, 8, 11], 'Royals': [9, 10], 'kings': [5]}

# %%
# return the teams which have participated three or more times in IPL

df.groupby('Team').filter(lambda x: len(x) >= 3)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 4    Kings     3  2014     741
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690

# %%
grouped = df.groupby('Team')
score = lambda x: (x - x.mean()) / x.std()*10
grouped.transform(score)
# Out:
#          Rank       Year     Points
# 0  -15.000000 -11.618950  12.843272
# 1    5.000000  -3.872983   3.020286
# 2   -7.071068  -7.071068   7.071068
# 3    7.071068   7.071068  -7.071068
# 4   11.547005 -10.910895  -8.608621
# 5         NaN        NaN        NaN
# 6   -5.773503   2.182179  -2.360428
# 7   -5.773503   8.728716  10.969049
# 8    5.000000   3.872983  -7.705963
# 9    7.071068  -7.071068  -7.071068
# 10  -7.071068   7.071068   7.071068
# 11   5.000000  11.618950  -8.157595

# %% [markdown]
# ### Reindexing

# %% [markdown]
# Reindexing changes the row labels and column labels of a DataFrame. To reindex means to conform the data to match a given set of labels along a particular axis.

# %%
N=20

df = pd.DataFrame({
   'A': pd.date_range(start='2016-01-01',periods=N,freq='D'),
   'x': np.linspace(0,stop=N-1,num=N),
   'y': np.random.rand(N),
   'C': np.random.choice(['Low','Medium','High'],N).tolist(),
   'D': np.random.normal(100, 10, size=(N)).tolist()
})

# %%
df.head()
# Out:
#            A    x         y       C           D
# 0 2016-01-01  0.0  0.412513    High   95.720793
# 1 2016-01-02  1.0  0.959497     Low  117.481701
# 2 2016-01-03  2.0  0.578357     Low  103.980667
# 3 2016-01-04  3.0  0.666903  Medium  107.104719
# 4 2016-01-05  4.0  0.075866    High   97.281215

# %%
df_reindexed = df.reindex(index=[0,2,5], columns=['A', 'C', 'B'])
df_reindexed.head()
# Out:
#            A     C   B
# 0 2016-01-01  High NaN
# 2 2016-01-03   Low NaN
# 5 2016-01-06  High NaN

# %%
# the df1 DataFrame is altered and reindexed like df2. 
# The column names should be matched or else NAN will be added for the entire column label.

df1 = pd.DataFrame(np.random.randn(10,3),columns=['col1','col2','col3'])
df2 = pd.DataFrame(np.random.randn(7,3),columns=['col1','col2','col3'])

df1 = df1.reindex_like(df2)

# %%
df1
# Out:
#        col1      col2      col3
# 0  0.548546  0.276981  1.084610
# 1  0.510689  0.708925  0.797318
# 2 -0.214159  0.569153  1.076981
# 3 -0.651547  1.392989 -0.479085
# 4 -1.594416 -1.376820 -0.552338
# 5  0.530467 -1.671947  0.848765
# 6  0.620069  1.062799 -0.364201

# %%
df1 = pd.DataFrame(np.random.randn(6,3),columns=['col1','col2','col3'])
df2 = pd.DataFrame(np.random.randn(2,3),columns=['col1','col2','col3'])
df2
# Out:
#        col1      col2      col3
# 0  0.238447 -0.097355 -0.617779
# 1 -0.189583 -0.169457  0.298964

# %%
df1
# Out:
#        col1      col2      col3
# 0  0.857821  1.730052  1.164488
# 1 -1.302571 -0.536478  0.040074
# 2  1.436630  0.724463 -0.930220
# 3  2.107922 -1.214441  1.968762
# 4 -0.449474 -0.361504  0.760734
# 5  0.234362  0.973634  0.109009

# %%
df2.reindex_like(df1)
# Out:
#        col1      col2      col3
# 0  0.238447 -0.097355 -0.617779
# 1 -0.189583 -0.169457  0.298964
# 2       NaN       NaN       NaN
# 3       NaN       NaN       NaN
# 4       NaN       NaN       NaN
# 5       NaN       NaN       NaN

# %%
# Now Fill the NAN's with preceding Values
print ("Data Frame with Forward Fill:")
df2.reindex_like(df1,method='ffill')
# Out:
# Data Frame with Forward Fill:
#        col1      col2      col3
# 0  0.238447 -0.097355 -0.617779
# 1 -0.189583 -0.169457  0.298964
# 2 -0.189583 -0.169457  0.298964
# 3 -0.189583 -0.169457  0.298964
# 4 -0.189583 -0.169457  0.298964
# 5 -0.189583 -0.169457  0.298964

# %%
# Limit specifies the maximum count of consecutive matches. 
# Now Fill the NAN's with preceding Values
# only the 2nd row is filled by the preceding 1st row. Then, the rows are left as they are.

print ("Data Frame with Forward Fill limiting to 1:")
df2.reindex_like(df1,method='ffill',limit=1)
# Out:
# Data Frame with Forward Fill limiting to 1:
#        col1      col2      col3
# 0  0.238447 -0.097355 -0.617779
# 1 -0.189583 -0.169457  0.298964
# 2 -0.189583 -0.169457  0.298964
# 3       NaN       NaN       NaN
# 4       NaN       NaN       NaN
# 5       NaN       NaN       NaN

# %% [markdown]
# ### Renaming

# %%
df1 = pd.DataFrame(np.random.randn(6,3),columns=['col1','col2','col3'])
df1
# Out:
#        col1      col2      col3
# 0 -1.081591  0.114238 -0.632456
# 1  0.360762  0.065571 -2.074396
# 2  0.074566  0.081261 -0.273432
# 3  0.618863  0.140536  0.666690
# 4 -0.212950  1.164272 -1.063245
# 5  1.249912 -1.129504 -0.898480

# %%
df1.rename(columns={'col1' : 'c1', 'col2' : 'c2'},index = {0 : 'apple', 1 : 'banana', 2 : 'durian'}, inplace=True)

# %%
df1
# Out:
#               c1        c2      col3
# apple  -1.081591  0.114238 -0.632456
# banana  0.360762  0.065571 -2.074396
# durian  0.074566  0.081261 -0.273432
# 3       0.618863  0.140536  0.666690
# 4      -0.212950  1.164272 -1.063245
# 5       1.249912 -1.129504 -0.898480

# %% [markdown]
# ### Sorting

# %%
unsorted_df=pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns=['col2','col1'])

# %%
unsorted_df
# Out:
#        col2      col1
# 1  1.061745 -0.344866
# 4 -0.847985 -0.235025
# 6  0.229354  0.809589
# 2 -1.211280 -0.887225
# 3 -0.240628 -0.255975
# 5 -1.620696  0.223087
# 9  0.876784 -1.654611
# 8 -0.348569 -0.079838
# 0  0.770913 -0.727050
# 7 -0.665182  0.087365

# %% [markdown]
# #### By label

# %% [markdown]
# Using the sort_index() method, by passing the axis arguments and the order of sorting, DataFrame can be sorted. By default, sorting is done on row labels in ascending order.

# %%
sorted_df=unsorted_df.sort_index()
sorted_df
# Out:
#        col2      col1
# 0  0.770913 -0.727050
# 1  1.061745 -0.344866
# 2 -1.211280 -0.887225
# 3 -0.240628 -0.255975
# 4 -0.847985 -0.235025
# 5 -1.620696  0.223087
# 6  0.229354  0.809589
# 7 -0.665182  0.087365
# 8 -0.348569 -0.079838
# 9  0.876784 -1.654611

# %%
sorted_df = unsorted_df.sort_index(ascending=False)
sorted_df
# Out:
#        col2      col1
# 9  0.876784 -1.654611
# 8 -0.348569 -0.079838
# 7 -0.665182  0.087365
# 6  0.229354  0.809589
# 5 -1.620696  0.223087
# 4 -0.847985 -0.235025
# 3 -0.240628 -0.255975
# 2 -1.211280 -0.887225
# 1  1.061745 -0.344866
# 0  0.770913 -0.727050

# %% [markdown]
# By passing the axis argument with a value 0 or 1, the sorting can be done on the column labels. By default, axis=0, sort by row.

# %%
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])
sorted_df=unsorted_df.sort_index(axis=0)
sorted_df
# Out:
#        col2      col1
# 0 -0.195912 -0.004858
# 1 -1.217805  0.540311
# 2  0.258384  1.123267
# 3 -1.504843  1.861210
# 4 -1.310063 -0.443032
# 5  1.111717  0.301951
# 6  0.360210 -0.071769
# 7 -0.130248 -0.561206
# 8 -1.148398  1.030422
# 9 -0.061878 -1.026474

# %% [markdown]
# #### By Value

# %% [markdown]
# 'by' argument takes a list of column values

# %%
unsorted_df = pd.DataFrame({'col1':[2,1,1,1],'col2':[1,3,2,4]})
sorted_df = unsorted_df.sort_values(by='col1')
sorted_df
# Out:
#    col1  col2
# 1     1     3
# 2     1     2
# 3     1     4
# 0     2     1

# %%
unsorted_df = pd.DataFrame({'col1':[2,1,1,1],'col2':[1,3,2,4]})
sorted_df = unsorted_df.sort_values(by=['col1','col2'])
sorted_df
# Out:
#    col1  col2
# 2     1     2
# 1     1     3
# 3     1     4
# 0     2     1

# %% [markdown]
# #### Sorting Algorithm

# %% [markdown]
# sort_values() provides a provision to choose the algorithm from mergesort, heapsort and quicksort. <b>Mergesort</b> is the only stable algorithm.

# %%
unsorted_df = pd.DataFrame({'col1':[2,1,1,1],'col2':[1,3,2,4]})
sorted_df = unsorted_df.sort_values(by='col1' ,kind='mergesort')
sorted_df
# Out:
#    col1  col2
# 1     1     3
# 2     1     2
# 3     1     4
# 0     2     1

# %% [markdown]
# ### Missing Data

# %% [markdown]
# NaN means Not a Number.

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f',
'h'],columns=['one', 'two', 'three'])

df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
df
# Out:
#         one       two     three
# a -1.598605 -0.453441 -0.868623
# b       NaN       NaN       NaN
# c -0.896890 -2.445449 -0.581742
# d       NaN       NaN       NaN
# e -1.135431 -0.619777  1.469648
# f -0.619504 -0.120285 -0.428429
# g       NaN       NaN       NaN
# h  0.089201  0.730162  1.539979

# %%
df['one'].isnull()
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
df['one'].isnull().sum()
# Out:
# 3

# %%
df['one'].notnull()
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f     True
# g    False
# h     True
# Name: one, dtype: bool

# %% [markdown]
# #### Calculations with Missing Data
# - When summing data, NA will be treated as Zero
# - If the data are all NA, then the result will be 0

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f','h'],columns=['one', 'two', 'three'])
df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
df
# Out:
#         one       two     three
# a  1.342219 -0.313041 -1.421305
# b       NaN       NaN       NaN
# c  0.170004 -0.229328 -0.166713
# d       NaN       NaN       NaN
# e  0.863130 -1.384935 -0.003466
# f  1.522088 -0.886376 -1.243997
# g       NaN       NaN       NaN
# h -1.240876  1.642807  0.256493

# %%
df['one'].sum()
# Out:
# 2.6565651034260913

# %%
df = pd.DataFrame(index=[0,1,2,3,4,5],columns=['one','two'])
df
# Out:
#    one  two
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
# 5  NaN  NaN

# %%
df['one'].sum()
# Out:
# 0

# %% [markdown]
# #### Cleaning / Filling Missing Data

# %%
# Replace NaN with a Scalar Value

df = pd.DataFrame(np.random.randn(3, 3), index=['a', 'c', 'e'],columns=['one','two', 'three'])
df = df.reindex(['a', 'b', 'c'])
df
# Out:
#         one       two     three
# a -0.363998 -0.384976  0.210560
# b       NaN       NaN       NaN
# c -0.281227 -1.680371 -1.648155

# %%
# dealing with empty cells -> insert a new value instead
# The fillna() method allows us to replace empty cells with a value
df.fillna(0)
# Out:
#         one       two     three
# a -0.363998 -0.384976  0.210560
# b  0.000000  0.000000  0.000000
# c -0.281227 -1.680371 -1.648155

# %%
df["one"].fillna(130, inplace = True)
df
# Out:
#           one       two     three
# a   -0.363998 -0.384976  0.210560
# b  130.000000       NaN       NaN
# c   -0.281227 -1.680371 -1.648155

# %%
df = pd.DataFrame(np.random.randn(3, 3), index=['a', 'c', 'e'],columns=['one','two', 'three'])
df = df.reindex(['a', 'b', 'c'])
df
# Out:
#         one       two     three
# a  0.244682 -0.591482  1.674011
# b       NaN       NaN       NaN
# c -1.568754 -0.518786  0.147924

# %%
# Replace Using Mean, Median, or Mode

x= df["one"].mean()
df["one"].fillna(x, inplace = True)
df
# Out:
#         one       two     three
# a  0.244682 -0.591482  1.674011
# b -0.662036       NaN       NaN
# c -1.568754 -0.518786  0.147924

# %%
x= df["two"].median()
df["two"].fillna(x, inplace = True)
df
# Out:
#         one       two     three
# a  0.244682 -0.591482  1.674011
# b -0.662036 -0.555134       NaN
# c -1.568754 -0.518786  0.147924

# %%
x= df["three"].mode()[0]
df["three"].fillna(x, inplace = True)
df
# Out:
#         one       two     three
# a  0.244682 -0.591482  1.674011
# b -0.662036 -0.555134  0.147924
# c -1.568754 -0.518786  0.147924

# %%
df["three"].mode()
# Out:
# 0    0.147924
# dtype: float64

# %%
df["three"].mode()[0]
# Out:
# 0.14792387626802458

# %%
# Drop Missing Values

df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f','h'],columns=['one', 'two', 'three'])
df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
df
# Out:
#         one       two     three
# a  0.821219  0.166081  0.949285
# b       NaN       NaN       NaN
# c -1.388269 -0.309105  2.100169
# d       NaN       NaN       NaN
# e -1.099827  1.085305 -1.004876
# f  1.425172 -0.507467 -0.483810
# g       NaN       NaN       NaN
# h -2.408526 -1.054944 -1.739009

# %%
# By default, the dropna() method returns a new DataFrame, and will not change the original.
# If you want to change the original DataFrame, use the inplace = True argument
df.dropna()
# Out:
#         one       two     three
# a  0.821219  0.166081  0.949285
# c -1.388269 -0.309105  2.100169
# e -1.099827  1.085305 -1.004876
# f  1.425172 -0.507467 -0.483810
# h -2.408526 -1.054944 -1.739009

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f','h'],columns=['one', 'two', 'three'])
df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
df
# Out:
#         one       two     three
# a  0.220080  0.346756  0.310301
# b       NaN       NaN       NaN
# c  0.269169  0.545510 -0.199716
# d       NaN       NaN       NaN
# e  1.317899 -0.027829 -0.322301
# f -1.503127 -0.425026 -0.872601
# g       NaN       NaN       NaN
# h -0.848553  0.710432 -0.348109

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [a, b, c, d, e, f, g, h]

# %%
# Replace Missing (or) Generic Values

df = pd.DataFrame({'one':[10,10,30,40,50,2000], 'two':[1000,1000,30,40,50,60]})
df
# Out:
#     one   two
# 0    10  1000
# 1    10  1000
# 2    30    30
# 3    40    40
# 4    50    50
# 5  2000    60

# %%
df.replace({1000:10,2000:60})
# Out:
#    one  two
# 0   10   10
# 1   10   10
# 2   30   30
# 3   40   40
# 4   50   50
# 5   60   60

# %% [markdown]
# #### Removing Duplicates

# %% [markdown]
# The duplicated() method returns a Boolean values for each row. Returns True for every row that is a duplicate, othwerwise False

# %%
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#     one   two
# 0    10  1000
# 2    30    30
# 3    40    40
# 4    50    50
# 5  2000    60

# %% [markdown]
# ###  Merging DataFrames

# %% [markdown]
# Merge and append are two of the most common operations that are performed in data analysis.

# %% [markdown]
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,left_index=False, right_index=False, sort=True)

# %% [markdown]
# - left − A DataFrame object.
# - right − Another DataFrame object.
# - on − Columns (names) to join on. Must be found in both the left and right DataFrame objects.
# - left_on − Columns from the left DataFrame to use as keys. Can either be column names or arrays with length equal to the length of the DataFrame.
# - right_on − Columns from the right DataFrame to use as keys. Can either be column names or arrays with length equal to the length of the DataFrame.
# - left_index − If True, use the index (row labels) from the left DataFrame as its join key(s). In case of a DataFrame with a MultiIndex (hierarchical), the number of levels must match the number of join keys from the right DataFrame.
# - right_index − Same usage as left_index for the right DataFrame.
# - how − One of 'left', 'right', 'outer', 'inner'. Defaults to inner. Each method has been described below.
# - sort − Sort the result DataFrame by the join keys in lexicographical order. Defaults to True, setting to False will improve the performance substantially in many cases.

# %%
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame(
   {'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})

# %%
left
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5

# %%
right
# Out:
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5

# %%
pd.merge(left,right,on='id')
# Out:
#    id  Name_x subject_id_x Name_y subject_id_y
# 0   1    Alex         sub1  Billy         sub2
# 1   2     Amy         sub2  Brian         sub4
# 2   3   Allen         sub4   Bran         sub3
# 3   4   Alice         sub6  Bryce         sub6
# 4   5  Ayoung         sub5  Betty         sub5

# %%
pd.merge(left,right,on=['id','subject_id'])
# Out:
#    id  Name_x subject_id Name_y
# 0   4   Alice       sub6  Bryce
# 1   5  Ayoung       sub5  Betty

# %% [markdown]
# - left  : LEFT OUTER JOIN  : Use keys from left object
# - right : RIGHT OUTER JOIN : Use keys from right object
# - outer : FULL OUTER JOIN  : Use union of keys
# - inner : INNER JOIN       : Use intersection of keys

# %%
pd.merge(left, right, on='subject_id', how='left')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0     1    Alex       sub1   NaN    NaN
# 1     2     Amy       sub2   1.0  Billy
# 2     3   Allen       sub4   2.0  Brian
# 3     4   Alice       sub6   4.0  Bryce
# 4     5  Ayoung       sub5   5.0  Betty

# %%
pd.merge(left, right, on='subject_id', how='right')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0   2.0     Amy       sub2     1  Billy
# 1   3.0   Allen       sub4     2  Brian
# 2   NaN     NaN       sub3     3   Bran
# 3   4.0   Alice       sub6     4  Bryce
# 4   5.0  Ayoung       sub5     5  Betty

# %%
pd.merge(left, right, how='outer', on='subject_id')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0   1.0    Alex       sub1   NaN    NaN
# 1   2.0     Amy       sub2   1.0  Billy
# 2   3.0   Allen       sub4   2.0  Brian
# 3   4.0   Alice       sub6   4.0  Bryce
# 4   5.0  Ayoung       sub5   5.0  Betty
# 5   NaN     NaN       sub3   3.0   Bran

# %%
pd.merge(left, right, on='subject_id', how='inner')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0     2     Amy       sub2     1  Billy
# 1     3   Allen       sub4     2  Brian
# 2     4   Alice       sub6     4  Bryce
# 3     5  Ayoung       sub5     5  Betty

# %%
one = pd.DataFrame({
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5'],
   'Marks_scored':[98,90,87,69,78]},
   index=[1,2,3,4,5])

two = pd.DataFrame({
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5'],
   'Marks_scored':[89,80,79,97,88]},
   index=[1,2,3,4,5])

# %%
one
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78

# %%
two
# Out:
#     Name subject_id  Marks_scored
# 1  Billy       sub2            89
# 2  Brian       sub4            80
# 3   Bran       sub3            79
# 4  Bryce       sub6            97
# 5  Betty       sub5            88

# %%
pd.concat([one,two])
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
pd.concat([one,two],keys=['x','y'])
# Out:
#        Name subject_id  Marks_scored
# x 1    Alex       sub1            98
#   2     Amy       sub2            90
#   3   Allen       sub4            87
#   4   Alice       sub6            69
#   5  Ayoung       sub5            78
# y 1   Billy       sub2            89
#   2   Brian       sub4            80
#   3    Bran       sub3            79
#   4   Bryce       sub6            97
#   5   Betty       sub5            88

# %%
pd.concat([one,two],keys=['x','y'],ignore_index=True)
# Out:
#      Name subject_id  Marks_scored
# 0    Alex       sub1            98
# 1     Amy       sub2            90
# 2   Allen       sub4            87
# 3   Alice       sub6            69
# 4  Ayoung       sub5            78
# 5   Billy       sub2            89
# 6   Brian       sub4            80
# 7    Bran       sub3            79
# 8   Bryce       sub6            97
# 9   Betty       sub5            88

# %%
pd.concat([one,two],axis=1)
# Out:
#      Name subject_id  Marks_scored   Name subject_id  Marks_scored
# 1    Alex       sub1            98  Billy       sub2            89
# 2     Amy       sub2            90  Brian       sub4            80
# 3   Allen       sub4            87   Bran       sub3            79
# 4   Alice       sub6            69  Bryce       sub6            97
# 5  Ayoung       sub5            78  Betty       sub5            88

# %%
pd.concat([one,two],axis=0)
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
one.append(two)
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
one.append([two,one,two])
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88
