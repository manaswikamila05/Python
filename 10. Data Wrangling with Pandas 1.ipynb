# %%
import pandas as pd
import numpy as np

# %% [markdown]
# File required : Glassdoor Jobs Dataset.csv

# %%
df = pd.read_csv('Glassdoor Jobs Dataset.csv')

# %%
df.head()
# Out:
#                                 Unnamed: 0                Unnamed: 1  \
# 0                                      NaN                       NaN
# 1                                      NaN                       NaN
# 2                              Competitors                   Revenue
# 3  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 4                                       -1    $1 to $2 billion (USD)
#
#       GLASSDOOR JOBS              Unnamed: 3              Unnamed: 4  \
# 0                NaN                     NaN                     NaN
# 1                NaN                     NaN                     NaN
# 2             Sector                Industry          Ownership Type
# 3          Insurance      Insurance Carriers  Nonprofit Organization
# 4  Business Services  Research & Development        Company - Public
#
#   Unnamed: 5               Unnamed: 6    Unnamed: 7     Unnamed: 8  \
# ...

# %% [markdown]
# For some reason the top rows are yielding NANs. Let's check the dataset and inspect

# %%
# The first few rows are blanks as you saw when you opened the dataset in Excel/Sheets
# Let's go ahead and Skip them

# %% [markdown]
# ### Loading the dataset
#
# Read the dataset 'Glassdoor Jobs Dataset.csv' and load it into a dataframe. Note that it contains some blanks in the beginning.

# %%
# You can use the skiprows functionality of the dataset to do this.
df = pd.read_csv('Glassdoor Jobs Dataset.csv', skiprows = 3)

# %%
df.head()
# Out:
#                                          Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                       Revenue             Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                                 Industry           Ownership Type  Founded  \
# 0                     Insurance Carriers   Nonprofit Organization     1993
# 1                 Research & Development         Company - Public     1968
# 2                             Consulting  Private Practice / Firm     1981
# ...

# %%
df.columns
# Out:
# Index(['Competitors', 'Revenue', 'Sector', 'Industry', 'Ownership Type',
#        'Founded', 'Size', 'Headquarters', 'Location', 'Name', 'Rating',
#        'Description', 'Salary', 'Title', 'index'],
#       dtype='object')

# %%
# let's drop the index column
df.drop(['index'], axis=1,inplace=True)

# %%
df.head()
# Out:
#                                          Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                       Revenue             Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                                 Industry           Ownership Type  Founded  \
# 0                     Insurance Carriers   Nonprofit Organization     1993
# 1                 Research & Development         Company - Public     1968
# 2                             Consulting  Private Practice / Firm     1981
# ...

# %% [markdown]
# ### Formatting the columns
#
# Notice the column names. On checking the data dictionary, some of them describe the company demographics whereas the other columns denote the job role specific details. Right now, it's not very understandable which one's which. To make it more readable rename the columns by adding a prefix 'C_' for all the Company columns and a 'J_' prefix for all the Job columns

# %%
cols = df.columns

# %%
cols
# Out:
# Index(['Competitors', 'Revenue', 'Sector', 'Industry', 'Ownership Type',
#        'Founded', 'Size', 'Headquarters', 'Location', 'Name', 'Rating',
#        'Description', 'Salary', 'Title'],
#       dtype='object')

# %%
l1 = 'C_' + cols[0:11] 
l1
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating'],
#       dtype='object')

# %%
l2 = 'J_' + cols[11:]
l2
# Out:
# Index(['J_Description', 'J_Salary', 'J_Title'], dtype='object')

# %%
newlist = l1.append(l2)
newlist
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating', 'J_Description', 'J_Salary',
#        'J_Title'],
#       dtype='object')

# %%
df.columns = newlist

# %%
df.head(5)
# Out:
#                                        C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                     C_Revenue           C_Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                               C_Industry         C_Ownership Type  C_Founded  \
# 0                     Insurance Carriers   Nonprofit Organization       1993
# 1                 Research & Development         Company - Public       1968
# 2                             Consulting  Private Practice / Firm       1981
# ...

# %% [markdown]
# #### Bonus tip
# In the above case you were adding 2 different prefixes to the columns. In case a single prefix is to be added, you can use the **add_prefix** functionality. Here's a small demo

# %% [markdown]
# **df.add_prefix()**

# %%
# make a copy of the original dataframe
df2 = df.copy()

# %%
df2.add_prefix('Glassdoor_').head(5)
# Out:
#                              Glassdoor_C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#           Glassdoor_C_Revenue Glassdoor_C_Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                     Glassdoor_C_Industry Glassdoor_C_Ownership Type  \
# 0                     Insurance Carriers     Nonprofit Organization
# 1                 Research & Development           Company - Public
# 2                             Consulting    Private Practice / Firm
# 3  Electrical & Electronic Manufacturing           Company - Public
# ...

# %% [markdown]
# Similarly the **add_suffix** command addes a suffix to each of the column names

# %% [markdown]
# ### Reordering the Columns
#
# As per the given data dictionary and also for ease of understanding, the job role specific columns should be in the beginning and the company specific columns should be after that. Reorder the dataframe so that the columns as per this order.

# %%
# Let's develop the logic so that we can do it in one step

# %%
df.loc[:,:]
# Out:
#                                          C_Competitors  \
# 0              EmblemHealth, UnitedHealth Group, Aetna
# 1                                                   -1
# 2                                                   -1
# 3    MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4                 Commerce Signals, Cardlytics, Yodlee
# ..                                                 ...
# 684                                                 -1
# 685                                                 -1
# 686                     Luxoft, EPAM, Capgemini Invent
# 687                                                 -1
# 688                                           Sequenom
#
#                       C_Revenue                   C_Sector  \
# 0      Unknown / Non-Applicable                  Insurance
# 1        $1 to $2 billion (USD)          Business Services
# 2    $100 to $500 million (USD)          Business Services
# 3    $100 to $500 million (USD)              Manufacturing
# ...

# %%
df.loc[:,::2]
# Out:
#                                          C_Competitors  \
# 0              EmblemHealth, UnitedHealth Group, Aetna
# 1                                                   -1
# 2                                                   -1
# 3    MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4                 Commerce Signals, Cardlytics, Yodlee
# ..                                                 ...
# 684                                                 -1
# 685                                                 -1
# 686                     Luxoft, EPAM, Capgemini Invent
# 687                                                 -1
# 688                                           Sequenom
#
#                       C_Sector         C_Ownership Type  \
# 0                    Insurance   Nonprofit Organization
# 1            Business Services         Company - Public
# 2            Business Services  Private Practice / Firm
# 3                Manufacturing         Company - Public
# ...

# %%
# All job columns
list(df.columns[11:])
# Out:
# ['J_Description', 'J_Salary', 'J_Title']

# %%
# All company columns
list(df.columns[:11])
# Out:
# ['C_Competitors',
#  'C_Revenue',
#  'C_Sector',
#  'C_Industry',
#  'C_Ownership Type',
#  'C_Founded',
#  'C_Size',
#  'C_Headquarters',
#  'C_Location',
#  'C_Name',
#  'C_Rating']

# %%
df[list(df.columns[11:]) + list(df.columns[:11])].head()
# Out:
#                                        J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# 1  Secure our Nation, Ignite your Future\n\nJoin ...
# 2  Overview\n\n\nAnalysis Group is one of the lar...
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4  Data Scientist\nAffinity Solutions / Marketing...
#
#                        J_Salary            J_Title  \
# 0  $137K-$171K (Glassdoor est.)  Sr Data Scientist
# 1  $137K-$171K (Glassdoor est.)     Data Scientist
# 2  $137K-$171K (Glassdoor est.)     Data Scientist
# 3  $137K-$171K (Glassdoor est.)     Data Scientist
# 4  $137K-$171K (Glassdoor est.)                NaN
#
#                                        C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
# ...

# %%
# All C columns are at the start and all J columns are at the end
# the columns could be reversed by slicing

# Slicing
df.loc[:,::-1]
# Out:
#                                J_Title                      J_Salary  \
# 0                    Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                       Data Scientist  $137K-$171K (Glassdoor est.)
# 2                       Data Scientist  $137K-$171K (Glassdoor est.)
# 3                       Data Scientist  $137K-$171K (Glassdoor est.)
# 4                                  NaN  $137K-$171K (Glassdoor est.)
# ..                                 ...                           ...
# 684                      Data Engineer   $79K-$131K (Glassdoor est.)
# 685                     Data Scientist   $79K-$131K (Glassdoor est.)
# 686                     Data Scientist   $79K-$131K (Glassdoor est.)
# 687  Data & Machine Learning Scientist   $79K-$131K (Glassdoor est.)
# 688  Data Scientist - Machine Learning   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...      3.1
# ...

# %%
df = df.loc[:,::-1]

# %%
df.head()
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4                NaN  $137K-$171K (Glassdoor est.)
#
#                                        J_Description C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...      3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...      4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...      3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...      3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...      2.9
#
#                     C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %% [markdown]
# Note that if you want your columns to be in specific order, there is no shortcut, other than to **specify the indices in a list and pass the list to df.loc[] locator.**

# %%
# With the columns in place, let's now check the datatypes of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   J_Title           684 non-null    object
#  1   J_Salary          689 non-null    object
#  2   J_Description     689 non-null    object
#  3   C_Rating          684 non-null    object
#  4   C_Name            689 non-null    object
#  5   C_Location        689 non-null    object
#  6   C_Headquarters    689 non-null    object
#  7   C_Size            689 non-null    object
#  8   C_Founded         689 non-null    int64
#  9   C_Ownership Type  689 non-null    object
#  10  C_Industry        689 non-null    object
#  11  C_Sector          689 non-null    object
#  12  C_Revenue         689 non-null    object
#  13  C_Competitors     689 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 75.5+ KB

# %% [markdown]
# ## Cleaning the dataset - I
#
# The company rating (C_rating) has `NaNs` and is of `object` type. Clean the column by imputing the nulls and converting the column to numeric type

# %% [markdown]
# ### Check if nulls are the only impurities present here and why the column is of 'object' type

# %%
# Let's directly convert it to a numeric type and see what results we get
# For NaNs we'll coerce the errors later, for now let's check if there are some other types of errors or not
pd.to_numeric(df.C_Rating)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "4.4*"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44024/3814015454.py in <module>
#       1 # Let's directly convert it to a numeric type and see what results we get
#       2 # For NaNs we'll coerce the errors later, for now let's check if there are some other types of errors or not
# ----> 3 pd.to_numeric(df.C_Rating)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# ...

# %% [markdown]
# Okay, based on the above error, apart from NaNs, it seems that some of the data contain impurities in them.  **This is because this might not be the only erroneous pattern** Let's inspect if indeed this is the case

# %% [markdown]
# **ValueError** observed in the stack trace. Pattern is of the form x.x

# %%
# One logic to check which types of errors exist can be to inspect the length of each of the entries in the C_Rating column
# Ideally the number should be the of the type " *.*" where * indicates a numeric digit. Hence the length should be 3
# If the length is more than 3, then it might contain an error.

for i in (df[~df['C_Rating'].isna()]['C_Rating']):
    if len(i)>3:
        print(i)
# Out:
# 4.4*
# /3.7
# 3.8*/
# 2*+.9

# %% [markdown]
# The rating column contains a few characters along with the numbers that deonte the rating. These characters need to be removed.

# %% [markdown]
# **Bonus method to find the rows which show error**

# %%
errors = []

for i in (df['C_Rating']):
   try: 
    pd.to_numeric(i)
   except ValueError:
    errors.append(i)
    
print(errors)
# Out:
# ['4.4*', '/3.7', '3.8*/', '2*+.9']

# %% [markdown]
# ### Check the nulls and impute it appropriately

# %%
# Let's check the NaN values
df[df['C_Rating'].isna()]
# Out:
#                         J_Title                      J_Salary  \
# 49               Data Scientist   $75K-$131K (Glassdoor est.)
# 67               Data Scientist   $79K-$131K (Glassdoor est.)
# 157  Experienced Data Scientist  $101K-$165K (Glassdoor est.)
# 350              Data Scientist  $122K-$146K (Glassdoor est.)
# 686              Data Scientist   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 49   Company Description:\nWhats it like to work at...      NaN
# 67   As a member of the Data Science team, this rol...      NaN
# 157  *******Please Apply using this link: https://a...      NaN
# 350  What will you be doing?\n\nThe Contractor shal...      NaN
# 686  As a member of the Data Science team, this rol...      NaN
#
#                                         C_Name       C_Location  \
# 49                             Quick Base\n4.3    Cambridge, MA
# 67                          Grid Dynamics\n4.0  Santa Clara, CA
# ...

# %% [markdown]
# We can see that the Company Rating has merged with the Company Name. So first, let's fill the NaN values with the correct rating

# %%
df['C_Rating'].dtype
# Out:
# dtype('O')

# %%
# let's store the indexes
ix = df[df['C_Rating'].isna()].index
ix
# Out:
# Int64Index([49, 67, 157, 350, 686], dtype='int64')

# %%
lis = []

for i in range(0,len(ix)):
    lis.append(df.iloc[ix[i]]['C_Name'].split('\n')[1])

# %%
lis
# Out:
# ['4.3', '4.0', '4.4', '4.7', '4.0']

# %%
df.iloc[ix,3] = lis

# %%
df.iloc[ix]
# Out:
#                         J_Title                      J_Salary  \
# 49               Data Scientist   $75K-$131K (Glassdoor est.)
# 67               Data Scientist   $79K-$131K (Glassdoor est.)
# 157  Experienced Data Scientist  $101K-$165K (Glassdoor est.)
# 350              Data Scientist  $122K-$146K (Glassdoor est.)
# 686              Data Scientist   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 49   Company Description:\nWhats it like to work at...      4.3
# 67   As a member of the Data Science team, this rol...      4.0
# 157  *******Please Apply using this link: https://a...      4.4
# 350  What will you be doing?\n\nThe Contractor shal...      4.7
# 686  As a member of the Data Science team, this rol...      4.0
#
#                                         C_Name       C_Location  \
# 49                             Quick Base\n4.3    Cambridge, MA
# 67                          Grid Dynamics\n4.0  Santa Clara, CA
# ...

# %% [markdown]
# Now we have transferred the rating data from the C_Name column to the C_Rating column.

# %%
df.C_Rating.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Convert the column to the correct datatype

# %%
# With the nulls imputed, we need to remove the impurities 
# Let's write a custom function to do the same

# %%
print(errors)
# Out:
# ['4.4*', '/3.7', '3.8*/', '2*+.9']

# %%
# Extract only numbers and decimal point

# %%
def cleaner(str):
    clean_str="".join(filter(lambda x: (x in "0123456789."), str))
    return float(clean_str)

# %%
cleaner('4.4*')
# Out:
# 4.4

# %%
cleaner('2*+.9')
# Out:
# 2.9

# %% [markdown]
# **Explanation** - The function `cleaner` takes a string and filters out all the numeric digits and the dot symbol, joins them and then converts the given string to a float value

# %%
df['C_Rating'] = df['C_Rating'].apply(cleaner)

# %%
df['C_Rating'].dtype
# Out:
# dtype('float64')

# %%
df['C_Rating'].describe()
# Out:
# count    689.000000
# mean       3.672859
# std        0.953591
# min        1.000000
# 25%        3.400000
# 50%        3.800000
# 75%        4.300000
# max        5.600000
# Name: C_Rating, dtype: float64

# %% [markdown]
# #### Clean the company name column

# %%
df.head(5)
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4                NaN  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...       4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...       3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...       2.9
#
#                     C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %%
df['C_Name']= df['C_Name'].apply(lambda x: x.split('\n')[0])

# %%
df.head()
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4                NaN  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...       4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...       3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...       2.9
#
#                C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# ...

# %% [markdown]
# #### Clean the Job_Title column by using the Mode functionality

# %%
df[df['J_Title'].isna()]
# Out:
#     J_Title                      J_Salary  \
# 4       NaN  $137K-$171K (Glassdoor est.)
# 9       NaN  $137K-$171K (Glassdoor est.)
# 38      NaN   $75K-$131K (Glassdoor est.)
# 290     NaN  $141K-$225K (Glassdoor est.)
# 396     NaN  $110K-$163K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 4    Data Scientist\nAffinity Solutions / Marketing...       2.9
# 9    Ready to write the best chapter of your career...       3.6
# 38   Job Title: Data Scientists\n\nJob Description\...       2.2
# 290  Work Authorization Those authorized to work in...       1.0
# 396  Meridian Knowledge Solutions, LLC, is the lead...       4.3
#
#                                   C_Name         C_Location C_Headquarters  \
# 4                     Affinity Solutions       New York, NY   New York, NY
# 9                     XSELL Technologies        Chicago, IL    Chicago, IL
# 38             Great-Circle Technologies      Chantilly, VA  Chantilly, VA
# ...

# %%
ix = df[df['J_Title'].isna()].index
ix
# Out:
# Int64Index([4, 9, 38, 290, 396], dtype='int64')

# %%
df['J_Title'].mode()[0]
# Out:
# 'Data Scientist'

# %%
# Imputing mode to the NaN rows
df.iloc[ix, 0] = df['J_Title'].mode()[0]

# %%
# Alternatively, imputing mode to the NaN rows

df.loc[df['J_Title'].isna(), 'J_Title'] = df['J_Title'].mode()[0]

# %%
df[df['J_Title'].isna()]
# Out:
# Empty DataFrame
# Columns: [J_Title, J_Salary, J_Description, C_Rating, C_Name, C_Location, C_Headquarters, C_Size, C_Founded, C_Ownership Type, C_Industry, C_Sector, C_Revenue, C_Competitors]
# Index: []

# %%
df.iloc[ix]
# Out:
#             J_Title                      J_Salary  \
# 4    Data Scientist  $137K-$171K (Glassdoor est.)
# 9    Data Scientist  $137K-$171K (Glassdoor est.)
# 38   Data Scientist   $75K-$131K (Glassdoor est.)
# 290  Data Scientist  $141K-$225K (Glassdoor est.)
# 396  Data Scientist  $110K-$163K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 4    Data Scientist\nAffinity Solutions / Marketing...       2.9
# 9    Ready to write the best chapter of your career...       3.6
# 38   Job Title: Data Scientists\n\nJob Description\...       2.2
# 290  Work Authorization Those authorized to work in...       1.0
# 396  Meridian Knowledge Solutions, LLC, is the lead...       4.3
#
#                                   C_Name         C_Location C_Headquarters  \
# 4                     Affinity Solutions       New York, NY   New York, NY
# 9                     XSELL Technologies        Chicago, IL    Chicago, IL
# ...

# %% [markdown]
# ## Cleaning the dataset - II
# There are -1s throughout the dataframe which are erroneous values. Remove all the rows which contains them.

# %%
df.head(10)
# Out:
#                                     J_Title                      J_Salary  \
# 0                         Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                            Data Scientist  $137K-$171K (Glassdoor est.)
# 2                            Data Scientist  $137K-$171K (Glassdoor est.)
# 3                            Data Scientist  $137K-$171K (Glassdoor est.)
# 4                            Data Scientist  $137K-$171K (Glassdoor est.)
# 5                            Data Scientist  $137K-$171K (Glassdoor est.)
# 6  Data Scientist / Machine Learning Expert  $137K-$171K (Glassdoor est.)
# 7                            Data Scientist  $137K-$171K (Glassdoor est.)
# 8          Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 9                            Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# ...

# %%
# We'll use the df.eq operator to find all the rows which contains -1
# It will return Boolean for each of the cells in the df

# %%
df.eq(-1)
# Out:
#      J_Title  J_Salary  J_Description  C_Rating  C_Name  C_Location  \
# 0      False     False          False     False   False       False
# 1      False     False          False     False   False       False
# 2      False     False          False     False   False       False
# 3      False     False          False     False   False       False
# 4      False     False          False     False   False       False
# ..       ...       ...            ...       ...     ...         ...
# 684    False     False          False     False   False       False
# 685    False     False          False     False   False       False
# 686    False     False          False     False   False       False
# 687    False     False          False     False   False       False
# 688    False     False          False     False   False       False
#
#      C_Headquarters  C_Size  C_Founded  C_Ownership Type  C_Industry  \
# 0             False   False      False             False       False
# ...

# %%
# Let's find the sum of -1s across each column
df.eq(-1).sum()
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters        0
# C_Size                0
# C_Founded           119
# C_Ownership Type      0
# C_Industry            0
# C_Sector              0
# C_Revenue             0
# C_Competitors         0
# dtype: int64

# %%
# Interesting that it's only showing -1s in C_founded but not in any other column
# like C-Competitors for which we can clearly see the -1s
# What's the mistake in the code shown above?

# %% [markdown]
# The code shown above doesn't account for **strings which are '-1'**. Hence we need to include that condition as well

# %%
df.eq("-1").sum()
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded             0
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# dtype: int64

# %%
# Let's use this nifty concat function which will do a bitwise OR operation since the values in both the dfs are Boolean
# Now it will show True for the ones which are encoded as "-1" as well

# %%
(df2.eq(-1) + df2.eq('-1'))
# Out:
#      C_Competitors  C_Revenue  C_Sector  C_Industry  C_Ownership Type  \
# 0            False      False     False       False             False
# 1             True      False     False       False             False
# 2             True      False     False       False             False
# 3            False      False     False       False             False
# 4            False      False     False       False             False
# ..             ...        ...       ...         ...               ...
# 684           True      False     False       False             False
# 685           True      False     False       False             False
# 686          False      False     False       False             False
# 687           True      False     False       False             False
# 688          False      False     False       False             False
#
#      C_Founded  C_Size  C_Headquarters  C_Location  C_Name  C_Rating  \
# ...

# %%
((df2.eq(-1) + df2.eq('-1')).sum())
# Out:
# C_Competitors       512
# C_Revenue            27
# C_Sector             71
# C_Industry           71
# C_Ownership Type     27
# C_Founded           119
# C_Size               27
# C_Headquarters       31
# C_Location            0
# C_Name                0
# C_Rating             50
# J_Description         0
# J_Salary              0
# J_Title               0
# dtype: int64

# %% [markdown]
# Clean the rows which have -1s in them
#
# We'll use a method where we convert the -1s to NaNs and then drop them directly with a single function

# %%
# replace the values of -1 and "-1" with null values and remove the null records completely.

# %%
cols = df.columns

# %%
for i in cols:
    df.loc[df[i].isin([-1,"-1"]), i] = np.NaN

# %%
df.isna().sum()
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded           119
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# dtype: int64

# %%
df.shape
# Out:
# (689, 14)

# %%
# drop rows with NULL values. 
# C_Competitors has 512 rows with NULL values, this would delete 512 rows from the dataframe having 689 rows
df.dropna(axis = 0,inplace = True)

# %%
df.shape
# Out:
# (172, 14)

# %%
df.isna().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# dtype: int64

# %%
df.head()
# Out:
#                              J_Title                      J_Salary  \
# 0                  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 3                     Data Scientist  $137K-$171K (Glassdoor est.)
# 4                     Data Scientist  $137K-$171K (Glassdoor est.)
# 8   Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 10                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                         J_Description  C_Rating  \
# 0   Description\n\nThe Senior Data Scientist is re...       3.1
# 3   JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 4   Data Scientist\nAffinity Solutions / Marketing...       2.9
# 8   Intuit is seeking a Staff Data Scientist to co...       4.4
# 10  Join our team dedicated to developing and exec...       4.5
#
#                 C_Name     C_Location          C_Headquarters  \
# 0          Healthfirst   New York, NY            New York, NY
# ...

# %%
df.reset_index(drop = True,inplace = True)

# %% [markdown]
# ## Perform hierarchical indexing using Company City and State

# %% [markdown]
# The location column has both the city and the state information

# %%
df.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2                    Data Scientist  $137K-$171K (Glassdoor est.)
# 3  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Data Scientist\nAffinity Solutions / Marketing...       2.9
# 3  Intuit is seeking a Staff Data Scientist to co...       4.4
# 4  Join our team dedicated to developing and exec...       4.5
#
#                C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             INFICON     Newton, MA  Bad Ragaz, Switzerland
# ...

# %%
df2 = df.copy()

# %%
df['C_City']= df['C_Location'].apply(lambda x: x.split(',')[0])

# %%
df.head(2)
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating       C_Name  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1  Healthfirst
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5      INFICON
#
#      C_Location          C_Headquarters                  C_Size  C_Founded  \
# 0  New York, NY            New York, NY  1001 to 5000 employees     1993.0
# 1    Newton, MA  Bad Ragaz, Switzerland   501 to 1000 employees     2000.0
#
#          C_Ownership Type                             C_Industry  \
# 0  Nonprofit Organization                     Insurance Carriers
# 1        Company - Public  Electrical & Electronic Manufacturing
#
#         C_Sector                   C_Revenue  \
# 0      Insurance    Unknown / Non-Applicable
# 1  Manufacturing  $100 to $500 million (USD)
#
# ...

# %%
df['C_State']= df['C_Location'].apply(lambda x: x.split(', ')[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44024/2087204640.py in <module>
# ----> 1 df['C_State']= df['C_Location'].apply(lambda x: x.split(', ')[1])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
# Index error
# This might have happened if one of the entries didn't have any state
# let's check
loc = list(df.C_Location.unique())
loc
# Out:
# ['New York, NY',
#  'Newton, MA',
#  'San Diego, CA',
#  'Herndon, VA',
#  'Saint Louis, MO',
#  'Richland, WA',
#  'Plano, TX',
#  'Appleton, WI',
#  'United States',
#  'Overland Park, KS',
#  'Santa Monica, CA',
#  'Portsmouth, NH',
#  'Cambridge, MA',
#  'San Francisco, CA',
#  'Fort Wayne, IN',
#  'Carson, CA',
#  'Santa Clara, CA',
#  'Winter Park, FL',
#  'Peoria, IL',
#  'Ipswich, MA',
#  'Carmel, IN',
#  'Washington, DC',
#  'Gaithersburg, MD',
#  'Denver, CO',
#  'Chantilly, VA',
#  'Reston, VA',
#  'Bethesda, MD',
#  'Dayton, OH',
#  'McLean, VA',
#  'Woodbridge, NJ',
#  'Vicksburg, MS',
#  'Blue Bell, PA',
#  'Chicago, IL',
#  'Redwood City, CA',
#  'San Carlos, CA',
#  'Waltham, MA',
#  'Fort Worth, TX',
#  'Fort Belvoir, VA',
#  'Oklahoma City, OK',
#  'Champaign, IL',
#  'Texas',
#  'Lebanon, IN',
#  'Melbourne, FL',
#  'Cleveland, OH',
#  'San Jose, CA',
#  'Danvers, MA',
#  'Livermore, CA',
#  'Northbrook, IL',
#  'Oshkosh, WI',
#  'Ann Arbor, MI',
# ...

# %%
for i in loc:
    if ',' not in i:
        print(i)
# Out:
# United States
# Texas

# %%
df[df['C_Location'].isin(['United States','Texas'])]
# Out:
#             J_Title                      J_Salary  \
# 10    Data Engineer   $75K-$131K (Glassdoor est.)
# 71   Data Scientist   $71K-$123K (Glassdoor est.)
# 133  Data Scientist  $212K-$331K (Glassdoor est.)
# 156  Data Scientist   $87K-$141K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 10   Chef Software is the industry leader in IT aut...       3.6
# 71   Who we are\n\n\nFueled by a fundamental belief...       3.8
# 133  Position: Data Scientist\nLocation: Denver\nSt...       3.6
# 156  Business Unit:\nCubic Transportation Systems\n...       3.3
#
#               C_Name     C_Location   C_Headquarters                   C_Size  \
# 10              Chef  United States      Seattle, WA     201 to 500 employees
# 71            PayPal          Texas     San Jose, CA         10000+ employees
# 133  Creative Circle  United States  Los Angeles, CA     201 to 500 employees
# ...

# %%
# Let's drop the United States Location rows as their locations are not specified
df2 = df[~(df['C_Location'] =='United States')].reset_index(drop = True)

# %%
df2.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2                    Data Scientist  $137K-$171K (Glassdoor est.)
# 3  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Data Scientist\nAffinity Solutions / Marketing...       2.9
# 3  Intuit is seeking a Staff Data Scientist to co...       4.4
# 4  Join our team dedicated to developing and exec...       4.5
#
#                C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             INFICON     Newton, MA  Bad Ragaz, Switzerland
# ...

# %%
df2.shape
# Out:
# (169, 15)

# %%
# Now let's do the split again and exclude the Texas one
# We'll add the state code TX later
df2['C_State']= df2.loc[df2['C_Location']!='Texas']['C_Location'].apply(lambda x: x.split(', ')[1])

# %%
df2.isnull().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# C_City              0
# C_State             1
# dtype: int64

# %%
df2['C_State'].fillna('TX', inplace = True)

# %%
df2.isnull().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# C_City              0
# C_State             0
# dtype: int64

# %%
# Let's sort it by State
df2 = df2.sort_values('C_State')

# %%
# Now let's create the hierarchical indexing without dropping the columns
df2.set_index(['C_State','C_City'], drop = False,inplace = True)

# %%
df2.head()
# Out:
#                                               J_Title  \
# C_State C_City
# CA      Santa Clara                    Data Scientist
#         Santa Clara                    Data Scientist
#         Carson       Data Analyst - Unilever Prestige
#         San Diego    Staff Data Scientist - Analytics
#         San Diego                Staff Data Scientist
#
#                                         J_Salary  \
# C_State C_City
# CA      Santa Clara  $79K-$131K (Glassdoor est.)
#         Santa Clara   $31K-$56K (Glassdoor est.)
#         Carson       $69K-$116K (Glassdoor est.)
#         San Diego    $99K-$132K (Glassdoor est.)
#         San Diego    $99K-$132K (Glassdoor est.)
#
#                                                          J_Description  \
# C_State C_City
# CA      Santa Clara  As a member of the Data Science team, this rol...
#         Santa Clara  As a member of the Data Science team, this rol...
#         Carson       Data Analyst - Unilever Prestige\nJob Code\n\n...
# ...

# %% [markdown]
# ### Clean the Salary column and extract Minimum Salary and Maximum Salary

# %%
df2.head()
# Out:
#                                               J_Title  \
# C_State C_City
# CA      Santa Clara                    Data Scientist
#         Santa Clara                    Data Scientist
#         Carson       Data Analyst - Unilever Prestige
#         San Diego    Staff Data Scientist - Analytics
#         San Diego                Staff Data Scientist
#
#                                         J_Salary  \
# C_State C_City
# CA      Santa Clara  $79K-$131K (Glassdoor est.)
#         Santa Clara   $31K-$56K (Glassdoor est.)
#         Carson       $69K-$116K (Glassdoor est.)
#         San Diego    $99K-$132K (Glassdoor est.)
#         San Diego    $99K-$132K (Glassdoor est.)
#
#                                                          J_Description  \
# C_State C_City
# CA      Santa Clara  As a member of the Data Science team, this rol...
#         Santa Clara  As a member of the Data Science team, this rol...
#         Carson       Data Analyst - Unilever Prestige\nJob Code\n\n...
# ...

# %% [markdown]
# - Thinking of using split()?
# - Think of the number of operations you need to do
# - Is there a better way?

# %% [markdown]
# ## Use Regular Expressions!

# %%
# Regular expressions can help in faster cleaning of data and process things much easily
# Explain a bit about this
import re
re.sub('[^0-9]','',"$137K-$171K (Glassdoor est.)")
# Out:
# '137171'

# %%
re.sub('[^0-9-]','',"$137K-$171K (Glassdoor est.)")
# Out:
# '137-171'

# %% [markdown]
# Substitute all non-numeric characters. Extract only the numeric characters

# %%
df2['Salary Estimate'] = df2['J_Salary'].apply(lambda x : re.sub('[^0-9-]','',x))
df2.head()
# Out:
#                                               J_Title  \
# C_State C_City
# CA      Santa Clara                    Data Scientist
#         Santa Clara                    Data Scientist
#         Carson       Data Analyst - Unilever Prestige
#         San Diego    Staff Data Scientist - Analytics
#         San Diego                Staff Data Scientist
#
#                                         J_Salary  \
# C_State C_City
# CA      Santa Clara  $79K-$131K (Glassdoor est.)
#         Santa Clara   $31K-$56K (Glassdoor est.)
#         Carson       $69K-$116K (Glassdoor est.)
#         San Diego    $99K-$132K (Glassdoor est.)
#         San Diego    $99K-$132K (Glassdoor est.)
#
#                                                          J_Description  \
# C_State C_City
# CA      Santa Clara  As a member of the Data Science team, this rol...
#         Santa Clara  As a member of the Data Science team, this rol...
#         Carson       Data Analyst - Unilever Prestige\nJob Code\n\n...
# ...

# %%
# minimum salary column at column 2

# %%
df2.insert(2, 'MinSal(K)', df2['Salary Estimate'].apply(lambda x: float(x.split('-')[0])))
df2.head()
# Out:
#                                               J_Title  \
# C_State C_City
# CA      Santa Clara                    Data Scientist
#         Santa Clara                    Data Scientist
#         Carson       Data Analyst - Unilever Prestige
#         San Diego    Staff Data Scientist - Analytics
#         San Diego                Staff Data Scientist
#
#                                         J_Salary  MinSal(K)  \
# C_State C_City
# CA      Santa Clara  $79K-$131K (Glassdoor est.)       79.0
#         Santa Clara   $31K-$56K (Glassdoor est.)       31.0
#         Carson       $69K-$116K (Glassdoor est.)       69.0
#         San Diego    $99K-$132K (Glassdoor est.)       99.0
#         San Diego    $99K-$132K (Glassdoor est.)       99.0
#
#                                                          J_Description  \
# C_State C_City
# CA      Santa Clara  As a member of the Data Science team, this rol...
#         Santa Clara  As a member of the Data Science team, this rol...
# ...

# %%
# maximum salary column at column 3

# %%
df2.insert(3, 'MaxSal(K)', df2['Salary Estimate'].apply(lambda x: float(x.split('-')[1])))
df2.head()
# Out:
#                                               J_Title  \
# C_State C_City
# CA      Santa Clara                    Data Scientist
#         Santa Clara                    Data Scientist
#         Carson       Data Analyst - Unilever Prestige
#         San Diego    Staff Data Scientist - Analytics
#         San Diego                Staff Data Scientist
#
#                                         J_Salary  MinSal(K)  MaxSal(K)  \
# C_State C_City
# CA      Santa Clara  $79K-$131K (Glassdoor est.)       79.0      131.0
#         Santa Clara   $31K-$56K (Glassdoor est.)       31.0       56.0
#         Carson       $69K-$116K (Glassdoor est.)       69.0      116.0
#         San Diego    $99K-$132K (Glassdoor est.)       99.0      132.0
#         San Diego    $99K-$132K (Glassdoor est.)       99.0      132.0
#
#                                                          J_Description  \
# C_State C_City
# CA      Santa Clara  As a member of the Data Science team, this rol...
# ...

# %%
df2[['MinSal','MaxSal']].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44024/2975928819.py in <module>
# ----> 1 df2[['MinSal','MaxSal']].describe()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %% [markdown]
# ## Binning the Min Sal and Max Sal columns

# %%
df3 = df2.copy()

# %%
df3['MinSalRange'] = pd.cut(df2['MinSal(K)'],bins=[56,100,160,330],labels = ['L','M','H'])

# %%
df3.head(10)
# Out:
#                                                                  J_Title  \
# C_State C_City
# CA      Santa Clara                                       Data Scientist
#         Santa Clara                                       Data Scientist
#         Carson                          Data Analyst - Unilever Prestige
#         San Diego                       Staff Data Scientist - Analytics
#         San Diego                                   Staff Data Scientist
#         Oxnard                                            Data Scientist
#         San Francisco                                     Data Scientist
#         San Francisco          Product Data Scientist - Ads Data Science
#         Fremont        Software Engineer (Data Scientist, C,C++,Linux...
#         San Jose                                   Data Engineer - Kafka
#
#                                            J_Salary  MinSal(K)  MaxSal(K)  \
# C_State C_City
# ...

# %%
# Let's ask pandas to do it automatically with pd.qcut

df3['MaxSalRange'] = pd.qcut(df3['MaxSal(K)'],q=3,labels = ['L','M','H'])

# %%
df3['MaxSalRange'].value_counts()
# Out:
# L    79
# H    51
# M    39
# Name: MaxSalRange, dtype: int64

# %%
df3.head(10)
# Out:
#                                                                  J_Title  \
# C_State C_City
# CA      Santa Clara                                       Data Scientist
#         Santa Clara                                       Data Scientist
#         Carson                          Data Analyst - Unilever Prestige
#         San Diego                       Staff Data Scientist - Analytics
#         San Diego                                   Staff Data Scientist
#         Oxnard                                            Data Scientist
#         San Francisco                                     Data Scientist
#         San Francisco          Product Data Scientist - Ads Data Science
#         Fremont        Software Engineer (Data Scientist, C,C++,Linux...
#         San Jose                                   Data Engineer - Kafka
#
#                                            J_Salary  MinSal(K)  MaxSal(K)  \
# C_State C_City
# ...
